# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2025.1.31)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.3.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.11/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->kaggle) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->kaggle) (3.10)

# %%
mkdir -p ~/.kaggle

# %%
# upload the kaggle.json file before running this
mv kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !pip install opendatasets
# Out:
# Requirement already satisfied: opendatasets in /usr/local/lib/python3.11/dist-packages (0.1.22)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from opendatasets) (4.67.1)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (from opendatasets) (1.6.17)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from opendatasets) (8.1.8)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (1.17.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (2025.1.31)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (2.32.3)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (2.3.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle->opendatasets) (6.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach->kaggle->opendatasets) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.11/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->kaggle->opendatasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->kaggle->opendatasets) (3.10)

# %%
# !kaggle datasets download -d nasrulhakim86/coughvid-wav
# Out:
# Dataset URL: https://www.kaggle.com/datasets/nasrulhakim86/coughvid-wav
# License(s): unknown
# Downloading coughvid-wav.zip to /content
# 100% 8.61G/8.61G [01:47<00:00, 58.2MB/s]
# 100% 8.61G/8.61G [01:47<00:00, 85.9MB/s]

# %%
import zipfile
import os

def unzip_file(zip_path, extract_to):
    """
    Unzips a given ZIP file to a specified directory.

    :param zip_path: Path to the ZIP file.
    :param extract_to: Directory where files should be extracted.
    """
    # Ensure the extraction directory exists
    os.makedirs(extract_to, exist_ok=True)

    # Open and extract the zip file
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)
        print(f"Extracted {zip_path} to {extract_to}")

# Example usage
zip_file_path = "/content/coughvid-wav.zip"  # Replace with your ZIP file path
extract_directory = "coughvid"  # Replace with desired extraction folder

unzip_file(zip_file_path, extract_directory)
# Out:
# Extracted /content/coughvid-wav.zip to coughvid

# %%
import pandas as pd

df=pd.read_csv('/content/coughvid/public_dataset/metadata_compiled.csv')
df.head()
df.to_csv("kaggle_metadata_compiled.csv")

# %%
# utilities
import os
import sys
from tqdm import tqdm
import random

# data manipulation
import numpy as np
import pandas as pd
import librosa
import matplotlib.pyplot as plt

# # pycaret
# from pycaret.classification import *

# scipy
from scipy import signal
from scipy.io import wavfile
from scipy.signal import butter,filtfilt
from scipy.signal import cwt
from scipy.signal import hilbert
from scipy.signal import resample
from scipy.signal import decimate
from scipy.signal import spectrogram
from scipy.signal.windows import get_window

# Set seed for reproducibility
seed_value= 32
os.environ['PYTHONHASHSEED']=str(seed_value)
random.seed(seed_value)
np.random.seed(seed_value)

# set variables
ROOT = 'coughvid/public_dataset/'
class_names = ['healthy','COVID-19','symptomatic']
audio_length = 22050

# load coughvid meta
data_raw = pd.read_csv(ROOT+'metadata_compiled.csv')
data_raw.head(3)
# Out:
#                                    uuid                          datetime  \
# 0  00014dcc-0f06-4c27-8c7b-737b18a2cf4c  2020-11-25T18:58:50.488301+00:00
# 1  00039425-7f3a-42aa-ac13-834aaa2b6b92  2020-04-13T21:30:59.801831+00:00
# 2  0007c6f1-5441-40e6-9aaf-a761d8f2da3b  2020-10-18T15:38:38.205870+00:00
#
#    cough_detected        SNR  latitude  longitude   age  gender  \
# 0          0.0155   7.326171      48.9        2.4   NaN     NaN
# 1          0.9609  16.151433      31.3       34.8  15.0    male
# 2          0.1643  16.217201       NaN        NaN  46.0  female
#
#   respiratory_condition fever_muscle_pain  ... quality_4 cough_type_4  \
# 0                   NaN               NaN  ...       NaN          NaN
# 1                 False             False  ...       NaN          NaN
# 2                 False             False  ...       NaN          NaN
#
#   dyspnea_4 wheezing_4 stridor_4 choking_4 congestion_4 nothing_4 diagnosis_4  \
# 0       NaN        NaN       NaN       NaN          NaN       NaN         NaN
# 1       NaN        NaN       NaN       NaN          NaN       NaN         NaN
# 2       NaN        NaN       NaN       NaN          NaN       NaN         NaN
#
#   severity_4
# 0        NaN
# 1        NaN
# 2        NaN
#
# [3 rows x 51 columns]

# %%
def split_by_physicians(df):
    column_names = ['uuid', 'datetime', 'cough_detected', 'SNR', 'latitude', 'longitude',
                    'age', 'gender', 'respiratory_condition', 'fever_muscle_pain', 'status',
                    'quality', 'cough_type', 'dyspnea', 'wheezing', 'stridor', 'choking',
                    'congestion', 'nothing', 'diagnosis', 'severity' ]
    physician_01 = df.iloc[:, 0:21]
    physician_01 = physician_01[physician_01.quality_1.notna()].reset_index(drop=True)
    physician_01.columns = column_names

    physician_02 = pd.concat([df.iloc[:, 0:11], df.iloc[:, 21:31]], axis=1)
    physician_02 = physician_02[physician_02.quality_2.notna()].reset_index(drop=True)
    physician_02.columns = column_names

    physician_03 = pd.concat([df.iloc[:, 0:11], df.iloc[:, 31:41]], axis=1)
    physician_03 = physician_03[physician_03.quality_3.notna()].reset_index(drop=True)
    physician_03.columns = column_names

    physician_04 = pd.concat([df.iloc[:, 0:11], df.iloc[:, 41:51]], axis=1)
    physician_04 = physician_04[physician_04.quality_4.notna()].reset_index(drop=True)
    physician_04.columns = column_names
    return physician_01, physician_02, physician_03, physician_04

def process_csv(df):
    #split by physicians
    physician_01, physician_02, physician_03, physician_04 = split_by_physicians(df)
    # combine into one dataframe
    df = pd.concat([physician_01,physician_02,physician_03,physician_04]).reset_index(drop=True)
    # drop null status
    df = df[df.status.notna()]
    # drop cough_detected < 0.8
    df = df[df.cough_detected >= 0.8 ]
    # select good and ok quality
    df = df[df.quality == 'good']
    # shuffle
    df = df.sample(frac=1).reset_index(drop=True)
    df = df[['uuid','status','cough_type', 'dyspnea', 'wheezing', 'stridor', 'choking', 'congestion', 'severity']]
    return df

# %%
processed_df = process_csv(data_raw)
processed_df.head(3)
processed_df.to_csv("processed_df.csv")

# %%
# here at load_feautures function we need to give the
import numpy as np
import librosa
import librosa.util
from tqdm import tqdm

# Constants
AUDIO_LENGTH = 11025  # Set appropriate audio length for padding
# ROOT = "path/to/audio/"  # Update this with the actual audio file path

def segment_cough(
    x: np.ndarray,
    fs: int,
    cough_padding: float = 0.2,
    min_cough_len: float = 0.2,
    th_l_multiplier: float = 0.1,
    th_h_multiplier: float = 2.0
):
    """
    Segments an audio signal into individual coughs based on power using a hysteresis comparator.

    Args:
        x (np.ndarray): Audio signal.
        fs (int): Sampling frequency.
        cough_padding (float): Padding duration before and after a cough in seconds.
        min_cough_len (float): Minimum length of a cough segment in seconds.
        th_l_multiplier (float): Lower threshold multiplier for segmentation.
        th_h_multiplier (float): Higher threshold multiplier for segmentation.

    Returns:
        list: List of segmented cough audio clips.
        np.ndarray: Mask indicating cough positions.
    """
    try:
        cough_mask = np.zeros(len(x), dtype=bool)

        # Define hysteresis thresholds
        rms = np.sqrt(np.mean(np.square(x)))
        seg_th_l = th_l_multiplier * rms
        seg_th_h = th_h_multiplier * rms

        # Segment coughs
        cough_segments = []
        padding = round(fs * cough_padding)
        min_cough_samples = round(fs * min_cough_len)
        cough_start = 0
        cough_in_progress = False
        tolerance = round(0.01 * fs)
        below_th_counter = 0

        for i, sample in enumerate(x**2):
            if cough_in_progress:
                if sample < seg_th_l:
                    below_th_counter += 1
                    if below_th_counter > tolerance:
                        cough_end = min(i + padding, len(x) - 1)
                        cough_in_progress = False
                        if (cough_end + 1 - cough_start - 2 * padding > min_cough_samples):
                            cough_segments.append(x[cough_start:cough_end + 1])
                            cough_mask[cough_start:cough_end + 1] = True
                elif i == len(x) - 1:
                    cough_end = i
                    cough_in_progress = False
                    if (cough_end + 1 - cough_start - 2 * padding > min_cough_samples):
                        cough_segments.append(x[cough_start:cough_end + 1])
                else:
                    below_th_counter = 0
            else:
                if sample > seg_th_h:
                    cough_start = max(i - padding, 0)
                    cough_in_progress = True

        return cough_segments, cough_mask
    except Exception as e:
        print(f"Error in segment_cough: {e}")
        return [], np.zeros(len(x), dtype=bool)


def extract_features(audio_data: np.ndarray, sample_rate: int) -> np.ndarray:
    """
    Extracts audio features including MFCCs, chroma, mel spectrogram, and spectral contrast.

    Args:
        audio_data (np.ndarray): Audio signal.
        sample_rate (int): Sampling rate of the audio.

    Returns:
        np.ndarray: Feature vector.
    """
    try:
        features = []
        stft = np.abs(librosa.stft(audio_data))

        mfcc = np.mean(librosa.feature.mfcc(y=audio_data, sr=sample_rate, n_mfcc=40).T, axis=0)
        features.extend(mfcc)

        chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0)
        features.extend(chroma)

        mel = np.mean(librosa.feature.melspectrogram(y=audio_data, sr=sample_rate).T, axis=0)
        features.extend(mel)

        fmin_val = 0.5 * sample_rate * 2 ** (-6)
        contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate, fmin=fmin_val).T, axis=0)
        features.extend(contrast)

        return np.array(features)
    except Exception as e:
        print(f"Error in extract_features: {e}")
        return np.array([])


def load_features(df) -> tuple[np.ndarray, np.ndarray]:
    """
    Loads and processes audio features from a dataframe containing UUIDs of recordings.

    Args:
        df (pd.DataFrame): DataFrame containing the UUIDs of the audio files.

    Returns:
        tuple: (Array of file names, Array of extracted features)
    """
    all_data, all_fnames = [], []

    for idx in tqdm(range(len(df))):
        try:
            fname = df.uuid.iloc[idx]
            path = f"{ROOT}{fname}.wav"

            # Load audio file
            audio, sample_rate = librosa.load(path, mono=True)

            # Segment coughs
            cough_segments, _ = segment_cough(
                audio,
                sample_rate,
                min_cough_len=0.1,
                cough_padding=0.1,
                th_l_multiplier=0.1,
                th_h_multiplier=2.0
            )

            # Process each segment
            for segment in cough_segments:
                if len(segment) > 8000:
                    audio_pad = librosa.util.fix_length(segment, size=AUDIO_LENGTH)

                    feature = extract_features(audio_pad, sample_rate)
                    if feature.size > 0:
                        all_data.append(feature)
                        all_fnames.append(fname)

        except Exception as e:
            print(f"Error processing file {fname}: {e}")

    return np.array(all_fnames), np.array(all_data)

# %%
uuid, X = load_features(processed_df)
# Out:
# 100%|██████████| 1680/1680 [05:56<00:00,  4.71it/s]

# %%
all_df=pd.DataFrame(X)

# %%
# Store each features in different dataframe so you can choose to train all features or individual
X_mfcc = X[:, 0:40]
X_chroma = X[:, 40:52]
X_mel = X[:, 52:180]
X_contrast = X[:, 180:]

# mfcc only
uuid_df = pd.DataFrame({'uuid':uuid})
mfcc_df = pd.DataFrame(X_mfcc)
mfcc_df.columns=["mfcc"+str(i) for i in range(1, X_mfcc.shape[1]+1)]
all_mfcc_df = pd.concat([uuid_df, mfcc_df], axis=1)

# mel spectogram only
mel_df = pd.DataFrame(X_mel)
mel_df.columns=["mel"+str(i) for i in range(1, X_mel.shape[1]+1)]
all_mel_df = pd.concat([uuid_df, mel_df], axis=1)

# chroma only
chroma_df = pd.DataFrame(X_chroma)
chroma_df.columns=["chr"+str(i) for i in range(1, X_chroma.shape[1]+1)]
all_chroma_df = pd.concat([uuid_df, chroma_df], axis=1)

# contrast only
contrast_df = pd.DataFrame(X_contrast)
contrast_df.columns=["con"+str(i) for i in range(1, X_contrast.shape[1]+1)]
all_contrast_df = pd.concat([uuid_df, contrast_df], axis=1)

# all features
all_df = pd.concat([uuid_df, mfcc_df, mel_df, chroma_df, contrast_df ], axis=1)
all_df.head(3)
# Out:
#                                    uuid       mfcc1      mfcc2      mfcc3  \
# 0  fed03a5c-6329-488c-a031-213ccdceabcf -213.578705  87.420441   8.120498
# 1  fed03a5c-6329-488c-a031-213ccdceabcf -325.151825  53.615295 -15.618588
# 2  09aaa59d-0263-4475-ab15-3bf00a32c0ef -174.282211  78.058968 -61.197327
#
#        mfcc4      mfcc5      mfcc6      mfcc7      mfcc8      mfcc9  ...  \
# 0  51.719822 -67.246979  44.662533 -22.648981  12.401959 -17.936531  ...
# 1  24.316902 -54.825096  27.862593 -28.378351  10.236364 -22.203346  ...
# 2  56.193581 -15.478662  19.696735 -44.306614  -5.602443 -43.272968  ...
#
#        chr12       con1       con2       con3       con4       con5  \
# 0  54.622154   17.69606  12.139623  13.534017  16.927916  16.967058
# 1   4.770071  14.004104   11.62694  14.831504   15.56434  14.922024
# 2  59.781357  17.418228  15.627757  18.171565  17.809531  15.766829
#
#         con6       con7     con8     con9
# 0  22.338747  59.761719  healthy  healthy
# 1  20.302576  50.034301  healthy  healthy
# 2  20.546662  57.380194  healthy  healthy
#
# [3 rows x 190 columns]

# %%
# Select only 'status' instead of 'cough_type'
label_df_status = processed_df[['uuid', 'status']].reset_index(drop=True)

# Merge features and labels
dataset_status = pd.merge(all_df, label_df_status, on='uuid')

# Remove any unknown or null values in 'status'
dataset_status = dataset_status[dataset_status.status.isin(['healthy', 'COVID-19', 'symptomatic'])]

dataset_status.head(3)
# Out:
#                                    uuid       mfcc1      mfcc2      mfcc3  \
# 0  fed03a5c-6329-488c-a031-213ccdceabcf -213.578705  87.420441   8.120498
# 1  fed03a5c-6329-488c-a031-213ccdceabcf -325.151825  53.615295 -15.618588
# 2  09aaa59d-0263-4475-ab15-3bf00a32c0ef -174.282211  78.058968 -61.197327
#
#        mfcc4      mfcc5      mfcc6      mfcc7      mfcc8      mfcc9  ...  \
# 0  51.719822 -67.246979  44.662533 -22.648981  12.401959 -17.936531  ...
# 1  24.316902 -54.825096  27.862593 -28.378351  10.236364 -22.203346  ...
# 2  56.193581 -15.478662  19.696735 -44.306614  -5.602443 -43.272968  ...
#
#       chr11     chr12       con1       con2       con3       con4       con5  \
# 0  0.435741  0.450481  17.696060  12.139623  13.534017  16.927916  16.967058
# 1  0.490802  0.609053  14.004104  11.626940  14.831504  15.564340  14.922024
# 2  0.473946  0.399070  17.418228  15.627757  18.171565  17.809531  15.766829
#
#         con6       con7   status
# 0  22.338747  59.761719  healthy
# 1  20.302576  50.034301  healthy
# 2  20.546662  57.380194  healthy
#
# [3 rows x 189 columns]

# %%
dataset_status.shape
# Out:
# (9778, 191)

# %%
dataset_status.status.value_counts()
# Out:
# status
# symptomatic    2897
# healthy        1866
# COVID-19       1699
# Name: count, dtype: int64

# %%
dataset_status.columns
# Out:
# Index(['uuid', 'mfcc1', 'mfcc2', 'mfcc3', 'mfcc4', 'mfcc5', 'mfcc6', 'mfcc7',
#        'mfcc8', 'mfcc9',
#        ...
#        'chr11', 'chr12', 'con1', 'con2', 'con3', 'con4', 'con5', 'con6',
#        'con7', 'status'],
#       dtype='object', length=189)

# %%
dataset_status.to_csv("data_to_train.csv")

# %%
import pandas as pd

# Assuming dataset_status is your DataFrame

for col in dataset_status.columns:
    print(col)
# Out:
# uuid
# mfcc1
# mfcc2
# mfcc3
# mfcc4
# mfcc5
# mfcc6
# mfcc7
# mfcc8
# mfcc9
# mfcc10
# mfcc11
# mfcc12
# mfcc13
# mfcc14
# mfcc15
# mfcc16
# mfcc17
# mfcc18
# mfcc19
# mfcc20
# mfcc21
# mfcc22
# mfcc23
# mfcc24
# mfcc25
# mfcc26
# mfcc27
# mfcc28
# mfcc29
# mfcc30
# mfcc31
# mfcc32
# mfcc33
# mfcc34
# mfcc35
# mfcc36
# mfcc37
# mfcc38
# mfcc39
# mfcc40
# mel1
# mel2
# mel3
# mel4
# mel5
# mel6
# mel7
# mel8
# mel9
# mel10
# mel11
# mel12
# mel13
# mel14
# mel15
# mel16
# mel17
# mel18
# mel19
# mel20
# mel21
# mel22
# mel23
# mel24
# mel25
# mel26
# mel27
# mel28
# mel29
# mel30
# mel31
# mel32
# mel33
# mel34
# mel35
# mel36
# mel37
# mel38
# mel39
# mel40
# mel41
# mel42
# mel43
# mel44
# mel45
# mel46
# mel47
# mel48
# mel49
# mel50
# mel51
# mel52
# mel53
# mel54
# mel55
# mel56
# mel57
# mel58
# mel59
# mel60
# mel61
# mel62
# mel63
# mel64
# mel65
# mel66
# mel67
# mel68
# mel69
# mel70
# mel71
# mel72
# mel73
# mel74
# mel75
# mel76
# mel77
# mel78
# mel79
# mel80
# mel81
# mel82
# mel83
# mel84
# mel85
# mel86
# mel87
# mel88
# mel89
# mel90
# mel91
# mel92
# mel93
# mel94
# mel95
# mel96
# mel97
# mel98
# mel99
# mel100
# mel101
# mel102
# mel103
# mel104
# mel105
# mel106
# mel107
# mel108
# mel109
# mel110
# mel111
# mel112
# mel113
# mel114
# mel115
# mel116
# mel117
# mel118
# mel119
# mel120
# mel121
# mel122
# mel123
# mel124
# mel125
# mel126
# mel127
# mel128
# chr1
# chr2
# chr3
# chr4
# chr5
# chr6
# chr7
# chr8
# chr9
# chr10
# chr11
# chr12
# con1
# con2
# con3
# con4
# con5
# con6
# con7
# status

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from colorama import Fore, Back, Style, init
from tabulate import tabulate
import warnings
warnings.filterwarnings('ignore')

def analyze_correlations(df, threshold=0.8):
    """
    Analyze correlations and identify highly correlated pairs
    """
    init()  # Initialize colorama

    # Get numeric columns
    numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns

    # Calculate correlation matrix
    corr_matrix = df[numeric_cols].corr().abs()

    # Find highly correlated pairs
    high_corr_pairs = []
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:
                high_corr_pairs.append({
                    'Feature 1': corr_matrix.columns[i],
                    'Feature 2': corr_matrix.columns[j],
                    'Correlation': corr_matrix.iloc[i, j]
                })

    # Create DataFrame of correlated pairs
    corr_pairs_df = pd.DataFrame(high_corr_pairs)

    # Sort by correlation strength
    if not corr_pairs_df.empty:
        corr_pairs_df = corr_pairs_df.sort_values('Correlation', ascending=False)

    return corr_pairs_df

def visualize_correlations(df, corr_pairs_df):
    """
    Create visualizations for correlation analysis
    """
    # Create correlation heatmap
    plt.figure(figsize=(12, 8))
    numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
    sns.heatmap(df[numeric_cols].corr(),
                cmap='RdYlBu_r',
                center=0,
                annot=False)
    plt.title('Feature Correlation Heatmap', pad=20)
    plt.tight_layout()

    # Create scatter plots for top correlated pairs
    if not corr_pairs_df.empty:
        top_pairs = corr_pairs_df.head(3)  # Show top 3 pairs
        plt.figure(figsize=(15, 5))
        for i, (_, row) in enumerate(top_pairs.iterrows(), 1):
            plt.subplot(1, 3, i)
            sns.scatterplot(data=df, x=row['Feature 1'], y=row['Feature 2'], alpha=0.5)
            plt.title(f'Correlation: {row["Correlation"]:.2f}')
            plt.xticks(rotation=45)
            plt.ylabel('')
        plt.tight_layout()

def remove_correlated_features(df, corr_pairs_df):
    """
    Remove one feature from each highly correlated pair
    """
    features_to_drop = set()

    if not corr_pairs_df.empty:
        for _, row in corr_pairs_df.iterrows():
            # Keep the first feature, drop the second
            features_to_drop.add(row['Feature 2'])

    # Create new dataframe without correlated features
    df_decorrelated = df.drop(columns=list(features_to_drop))

    return df_decorrelated, features_to_drop

def print_analysis_results(corr_pairs_df, dropped_features):
    """
    Print analysis results using colorama
    """
    print(f"{Fore.CYAN}=== Correlation Analysis Results ==={Style.RESET_ALL}")
    print(f"\n{Fore.GREEN}Number of highly correlated pairs: {Style.RESET_ALL}{len(corr_pairs_df)}")

    if not corr_pairs_df.empty:
        print(f"\n{Fore.YELLOW}Highly Correlated Feature Pairs:{Style.RESET_ALL}")
        print(tabulate(corr_pairs_df, headers='keys', tablefmt='fancy_grid', floatfmt='.3f'))

    print(f"\n{Fore.RED}Features Removed:{Style.RESET_ALL}")
    for feature in dropped_features:
        print(f"- {feature}")

def suggest_additional_checks():
    """
    Provide additional suggestions for feature analysis
    """
    suggestions = [
        ("Variance Analysis", "Check for low-variance features that might not contribute much information"),
        ("Mutual Information", "Calculate mutual information scores with target variable"),
        ("PCA Analysis", "Consider using PCA for dimensionality reduction while preserving variance"),
        ("Feature Importance", "Use model-based feature importance (Random Forest, XGBoost)"),
        ("ANOVA F-value", "For classification tasks, use ANOVA F-values to select features"),
        ("Chi-squared test", "For categorical features, use chi-squared tests for feature selection"),
        ("Recursive Feature Elimination", "Use RFE with cross-validation to select optimal features"),
        ("L1-based selection", "Use Lasso or ElasticNet for feature selection")
    ]

    print(f"\n{Fore.MAGENTA}=== Additional Analysis Suggestions ==={Style.RESET_ALL}")
    for method, description in suggestions:
        print(f"\n{Fore.BLUE}{method}:{Style.RESET_ALL}")
        print(f"  {description}")

def run_correlation_analysis(df):
    """
    Run the complete correlation analysis pipeline
    """
    # Analyze correlations
    corr_pairs_df = analyze_correlations(df)

    # Create visualizations
    visualize_correlations(df, corr_pairs_df)

    # Remove correlated features
    df_decorrelated, dropped_features = remove_correlated_features(df, corr_pairs_df)

    # Print results
    print_analysis_results(corr_pairs_df, dropped_features)

    # Save decorrelated dataset
    df_decorrelated.to_csv('decorrelated_features.csv', index=False)

    # Provide additional suggestions
    suggest_additional_checks()

    return df_decorrelated

# %%
df_decorrelated = run_correlation_analysis(df)

# %%
decorrelated = pd.read_csv('/content/decorrelated_features.csv')

# %%
decorrelated.columns
# Out:
# Index(['Unnamed: 0', 'uuid', 'mfcc1', 'mfcc2', 'mfcc3', 'mfcc4', 'mfcc5',
#        'mfcc6', 'mfcc7', 'mfcc8',
#        ...
#        'chr11', 'chr12', 'con1', 'con2', 'con3', 'con4', 'con5', 'con6',
#        'con7', 'status'],
#       dtype='object', length=109)

# %%
pip install colorama
# Out:
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama
# Successfully installed colorama-0.4.6

# %%
import tensorflow as tf
tf.keras.backend.clear_session()

# %%
# !pip install tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.23.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow-addons) (24.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Downloading tensorflow_addons-0.23.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 14.0 MB/s eta 0:00:00
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.4.1
#     Uninstalling typeguard-4.4.1:
#       Successfully uninstalled typeguard-4.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# inflect 7.5.0 requires typeguard>=4.0.1, but you have typeguard 2.13.3 which is incompatible.
# Successfully installed tensorflow-addons-0.23.0 typeguard-2.13.3

# %% [markdown]
# 20 epochos

# %%
# System imports
import os
import numpy as np
import joblib

# Data processing and visualization
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from colorama import Fore, Style

# Scikit-learn imports
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import SMOTE

# TensorFlow/Keras imports
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input,
    Conv2D,
    MaxPooling2D,
    BatchNormalization,
    Dropout,
    Flatten,
    Dense,
    LSTM,
    TimeDistributed
)
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Set random seeds for reproducibility
np.random.seed(612)
tf.random.set_seed(612)

class EnhancedCovidModelTrainerCNNLSTM:
    def __init__(self, save_dir='model_artifacts'):
        self.save_dir = save_dir
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)

        self.scaler = MinMaxScaler(feature_range=(-1, 1))
        self.label_encoder = LabelEncoder()
        self.model = None
        self.height = 1
        self.width = None
        self.channels = 1
        self.lstm_units = 128  # Reduced from 256
        self.sequence_length = 1
        self.dropout_rate = 0.3  # Increased from 0.2
        self.l2_lambda = 0.01  # Increased from 0.001

    def augment_data(self, X_train):
        """Apply data augmentation techniques."""
        # Add Gaussian noise
        noise = np.random.normal(0, 0.01, X_train.shape)
        X_train_noisy = X_train + noise

        # Create slight variations with scaling
        X_train_scaled = X_train * np.random.uniform(0.95, 1.05, X_train.shape)

        # Combine original and augmented data
        X_train_combined = np.concatenate([X_train, X_train_noisy, X_train_scaled])
        return X_train_combined

    def preprocess_data(self, sampled_data):
        print(Fore.BLUE + "[*] Loading and splitting data..." + Style.RESET_ALL)
        y_label = 'status'
        X = sampled_data.drop(columns=[y_label, 'uuid'])
        y = sampled_data[y_label]

        # Stratified split with larger training set
        X_train, X_test, y_train, y_test = train_test_split(
            X, y, test_size=0.2, random_state=612, stratify=y
        )

        print(Fore.BLUE + "[*] Normalizing features..." + Style.RESET_ALL)
        self.scaler.fit(X_train)
        X_train_norm = self.scaler.transform(X_train)
        X_test_norm = self.scaler.transform(X_test)

        print(Fore.BLUE + "[*] Encoding labels..." + Style.RESET_ALL)
        self.label_encoder.fit(y_train)
        y_train_enc = self.label_encoder.transform(y_train)
        y_test_enc = self.label_encoder.transform(y_test)

        # Handle NaN values
        nan_rows_train = np.isnan(X_train_norm).any(axis=1)
        X_train_norm = X_train_norm[~nan_rows_train]
        y_train_enc = y_train_enc[~nan_rows_train]

        nan_rows_test = np.isnan(X_test_norm).any(axis=1)
        X_test_norm = X_test_norm[~nan_rows_test]
        y_test_enc = y_test_enc[~nan_rows_test]

        self.width = X_train_norm.shape[1]

        print(Fore.BLUE + "[*] Reshaping data for CNN+LSTM..." + Style.RESET_ALL)
        X_train_norm = X_train_norm.reshape(-1, self.sequence_length, self.height, self.width, self.channels)
        X_test_norm = X_test_norm.reshape(-1, self.sequence_length, self.height, self.width, self.channels)

        print(Fore.BLUE + "[*] Applying data augmentation..." + Style.RESET_ALL)
        X_train_aug = self.augment_data(X_train_norm)
        y_train_aug = np.tile(y_train_enc, 3)  # Repeat labels for augmented data

        print(Fore.BLUE + "[*] Applying SMOTE with careful sampling..." + Style.RESET_ALL)
        X_train_flat = X_train_aug.reshape(-1, self.sequence_length * self.width)
        smote = SMOTE(random_state=612, k_neighbors=5)
        X_train_resampled, y_train_resampled = smote.fit_resample(X_train_flat, y_train_aug)
        X_train_resampled = X_train_resampled.reshape(-1, self.sequence_length, self.height, self.width, self.channels)

        print(Fore.GREEN + "[✓] Data preprocessing complete." + Style.RESET_ALL)
        return X_train_resampled, X_test_norm, y_train_resampled, y_test_enc

    def build_model(self):
        inputs = Input(shape=(self.sequence_length, self.height, self.width, self.channels))

        # First CNN block with increased regularization
        x = TimeDistributed(Conv2D(32, kernel_size=(1, 3), activation='relu', padding='same',
                                 kernel_regularizer=regularizers.l2(self.l2_lambda)))(inputs)
        x = TimeDistributed(BatchNormalization())(x)
        x = TimeDistributed(Conv2D(32, kernel_size=(1, 3), activation='relu', padding='same',
                                 kernel_regularizer=regularizers.l2(self.l2_lambda)))(x)
        x = TimeDistributed(BatchNormalization())(x)
        x = TimeDistributed(MaxPooling2D(pool_size=(1, 2)))(x)
        x = TimeDistributed(Dropout(self.dropout_rate))(x)

        # Second CNN block with residual connection
        residual = TimeDistributed(Conv2D(64, kernel_size=(1, 1), padding='same'))(x)
        x = TimeDistributed(Conv2D(64, kernel_size=(1, 3), activation='relu', padding='same',
                                 kernel_regularizer=regularizers.l2(self.l2_lambda)))(x)
        x = TimeDistributed(BatchNormalization())(x)
        x = TimeDistributed(Conv2D(64, kernel_size=(1, 3), activation='relu', padding='same',
                                 kernel_regularizer=regularizers.l2(self.l2_lambda)))(x)
        x = TimeDistributed(BatchNormalization())(x)
        x = tf.keras.layers.Add()([x, residual])
        x = TimeDistributed(MaxPooling2D(pool_size=(1, 2)))(x)
        x = TimeDistributed(Dropout(self.dropout_rate))(x)

        # Flatten CNN output
        x = TimeDistributed(Flatten())(x)

        # Bidirectional LSTM layers with reduced units
        x = tf.keras.layers.Bidirectional(LSTM(self.lstm_units, return_sequences=True,
                                             kernel_regularizer=regularizers.l2(self.l2_lambda)))(x)
        x = BatchNormalization()(x)
        x = Dropout(self.dropout_rate)(x)

        x = tf.keras.layers.Bidirectional(LSTM(self.lstm_units // 2,
                                             kernel_regularizer=regularizers.l2(self.l2_lambda)))(x)
        x = BatchNormalization()(x)
        x = Dropout(self.dropout_rate)(x)

        # Dense layers with reduced units and increased regularization
        dense1 = Dense(256, activation='relu',
                      kernel_regularizer=regularizers.l2(self.l2_lambda))(x)
        dense1 = BatchNormalization()(dense1)
        dense1 = Dropout(self.dropout_rate)(dense1)

        dense2 = Dense(128, activation='relu',
                      kernel_regularizer=regularizers.l2(self.l2_lambda))(dense1)
        dense2 = BatchNormalization()(dense2)
        dense2 = Dropout(self.dropout_rate)(dense2)

        skip_connection = Dense(128)(dense1)
        dense2 = tf.keras.layers.Add()([dense2, skip_connection])

        outputs = Dense(3, activation='softmax')(dense2)

        model = Model(inputs=inputs, outputs=outputs)

        # Using constant learning rate with Adam optimizer
        optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

        model.compile(
            optimizer=optimizer,
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy']
        )

        self.model = model
        return model

    def train(self, sampled_data, epochs=20, batch_size=256):  # Reduced batch size
        X_train_norm, X_test_norm, y_train_enc, y_test_enc = self.preprocess_data(sampled_data)

        if self.model is None:
            self.build_model()

        # Handle data repetition
        repetition_factor = X_train_norm.shape[0] // y_train_enc.shape[0]
        y_train_enc_repeated = np.repeat(y_train_enc, repetition_factor)

        remainder = X_train_norm.shape[0] % y_train_enc.shape[0]
        if remainder > 0:
            y_train_enc_repeated = np.concatenate([y_train_enc_repeated, y_train_enc[:remainder]])

        # Modified callbacks
        early_stopping = EarlyStopping(
            monitor='val_loss',
            patience=10,  # Reduced from 20
            restore_best_weights=True,
            min_delta=0.005  # Increased from 0.001
        )

        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.2,
            patience=5,
            min_lr=0.00001,
            verbose=1
        )

        checkpoint = ModelCheckpoint(
            f'{self.save_dir}/best_model.keras',
            monitor='val_accuracy',
            save_best_only=True,
            mode='max',
            save_weights_only=False
        )

        # Compute class weights
        class_weights = compute_class_weight(
            'balanced',
            classes=np.unique(y_train_enc_repeated),
            y=y_train_enc_repeated
        )
        class_weight_dict = dict(enumerate(class_weights))

        # Train the model
        history = self.model.fit(
            X_train_norm,
            y_train_enc_repeated,
            epochs=epochs,
            batch_size=batch_size,
            validation_data=(X_test_norm, y_test_enc),
            callbacks=[early_stopping, reduce_lr, checkpoint],
            class_weight=class_weight_dict,
            shuffle=True
        )

        # Model evaluation
        y_pred_probs = self.model.predict(X_test_norm)
        y_pred_classes = np.argmax(y_pred_probs, axis=1)

        y_pred_decoded = self.label_encoder.inverse_transform(y_pred_classes)
        y_test_decoded = self.label_encoder.inverse_transform(y_test_enc)

        print("\nClassification Report (Test Data):")
        report = classification_report(y_test_decoded, y_pred_decoded,
                                    target_names=self.label_encoder.classes_,
                                    output_dict=True)
        print(classification_report(y_test_decoded, y_pred_decoded,
                                  target_names=self.label_encoder.classes_))

        self.metrics = report
        self.test_accuracy = accuracy_score(y_test_decoded, y_pred_decoded) * 100
        print(f"Test Accuracy: {self.test_accuracy:.2f}%")

        # Plot confusion matrix
        cm = confusion_matrix(y_test_decoded, y_pred_decoded)
        plt.figure(figsize=(6, 5))
        sns.heatmap(cm, annot=True, fmt='d', cmap=plt.cm.Blues,
                   xticklabels=self.label_encoder.classes_,
                   yticklabels=self.label_encoder.classes_)
        plt.title('Confusion Matrix')
        plt.ylabel('True Label')
        plt.xlabel('Predicted Label')
        plt.tight_layout()
        plt.show()

        # Plot training history
        plt.figure(figsize=(12, 4))

        plt.subplot(1, 2, 1)
        plt.plot(history.history['loss'], label='Training Loss')
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.title('Model Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(history.history['accuracy'], label='Training Accuracy')
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
        plt.title('Model Accuracy')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.legend()

        plt.tight_layout()
        plt.show()

        self.save_artifacts()
        return history

    def save_artifacts(self):
        """Save all necessary model artifacts"""
        self.model.save(f'{self.save_dir}/covid_model_cnn_lstm.keras')
        joblib.dump(self.scaler, f'{self.save_dir}/scaler.pkl')
        joblib.dump(self.label_encoder, f'{self.save_dir}/label_encoder.pkl')
        model_params = {
            'height': self.height,
            'width': self.width,
            'channels': self.channels,
            'sequence_length': self.sequence_length,
            'lstm_units': self.lstm_units,
            'dropout_rate': self.dropout_rate,
            'l2_lambda': self.l2_lambda
        }
        joblib.dump(model_params, f'{self.save_dir}/model_params.pkl')

# %%
trainer = EnhancedCovidModelTrainerCNNLSTM()
history = trainer.train(decorrelated)
# Out:
# [*] Loading and splitting data...
# [*] Normalizing features...
# [*] Encoding labels...
# [*] Reshaping data for CNN+LSTM...
# [*] Applying data augmentation...
# [*] Applying SMOTE with careful sampling...
# [✓] Data preprocessing complete.
# Epoch 1/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 64s 44ms/step - accuracy: 0.3369 - loss: 22.7863 - val_accuracy: 0.4486 - val_loss: 13.8688 - learning_rate: 0.0010
# Epoch 2/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.3513 - loss: 12.5286 - val_accuracy: 0.2630 - val_loss: 8.6322 - learning_rate: 0.0010
# Epoch 3/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.3753 - loss: 7.8780 - val_accuracy: 0.4486 - val_loss: 5.7453 - learning_rate: 0.0010
# Epoch 4/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.4254 - loss: 5.2743 - val_accuracy: 0.4486 - val_loss: 4.0692 - learning_rate: 0.0010
# Epoch 5/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.4962 - loss: 3.7146 - val_accuracy: 0.4323 - val_loss: 3.0681 - learning_rate: 0.0010
# Epoch 6/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.5663 - loss: 2.7459 - val_accuracy: 0.2923 - val_loss: 2.5588 - learning_rate: 0.0010
# Epoch 7/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.6286 - loss: 2.1612 - val_accuracy: 0.4370 - val_loss: 2.1704 - learning_rate: 0.0010
# Epoch 8/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.6704 - loss: 1.8309 - val_accuracy: 0.4919 - val_loss: 1.9515 - learning_rate: 0.0010
# Epoch 9/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.7014 - loss: 1.6410 - val_accuracy: 0.5893 - val_loss: 1.7937 - learning_rate: 0.0010
# Epoch 10/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.7267 - loss: 1.5370 - val_accuracy: 0.5878 - val_loss: 1.8111 - learning_rate: 0.0010
# Epoch 11/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.7486 - loss: 1.4757 - val_accuracy: 0.5932 - val_loss: 1.8247 - learning_rate: 0.0010
# Epoch 12/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.7705 - loss: 1.4228 - val_accuracy: 0.5909 - val_loss: 1.8149 - learning_rate: 0.0010
# Epoch 13/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7881 - loss: 1.3898 - val_accuracy: 0.6110 - val_loss: 1.8163 - learning_rate: 0.0010
# Epoch 14/20
# 80/82 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7964 - loss: 1.3826
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.7965 - loss: 1.3823 - val_accuracy: 0.6210 - val_loss: 1.8064 - learning_rate: 0.0010
# Epoch 15/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8355 - loss: 1.2659 - val_accuracy: 0.6667 - val_loss: 1.6676 - learning_rate: 2.0000e-04
# Epoch 16/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.8937 - loss: 1.0213 - val_accuracy: 0.6682 - val_loss: 1.5988 - learning_rate: 2.0000e-04
# Epoch 17/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9155 - loss: 0.8930 - val_accuracy: 0.6705 - val_loss: 1.5738 - learning_rate: 2.0000e-04
# Epoch 18/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.9288 - loss: 0.8103 - val_accuracy: 0.6821 - val_loss: 1.4987 - learning_rate: 2.0000e-04
# Epoch 19/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.9237 - loss: 0.7901 - val_accuracy: 0.6651 - val_loss: 1.5673 - learning_rate: 2.0000e-04
# Epoch 20/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.9324 - loss: 0.7321 - val_accuracy: 0.6736 - val_loss: 1.5595 - learning_rate: 2.0000e-04
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
#
# Classification Report (Test Data):
#               precision    recall  f1-score   support
#
#     COVID-19       0.62      0.67      0.65       340
#      healthy       0.64      0.64      0.64       373
#  symptomatic       0.75      0.72      0.73       580
#
#     accuracy                           0.68      1293
#    macro avg       0.67      0.68      0.67      1293
# weighted avg       0.68      0.68      0.68      1293
#
# Test Accuracy: 68.21%

# %%
import os
import numpy as np
import joblib
import pandas as pd
import tensorflow as tf
from colorama import Fore, Style
from tabulate import tabulate

class CovidPredictorCNNLSTM:
    def __init__(self, model_dir='model_artifacts'):
        self.model_dir = model_dir
        self.load_artifacts()

    def load_artifacts(self):
        """Load trained model and preprocessing artifacts."""
        try:
            self.model = tf.keras.models.load_model(f'{self.model_dir}/covid_model_cnn_lstm.keras')
            self.scaler = joblib.load(f'{self.model_dir}/scaler.pkl')
            self.label_encoder = joblib.load(f'{self.model_dir}/label_encoder.pkl')
            model_params = joblib.load(f'{self.model_dir}/model_params.pkl')

            self.height = model_params['height']
            self.width = model_params['width']
            self.channels = model_params['channels']
            self.sequence_length = model_params['sequence_length']
            print("Model and artifacts loaded successfully.")
        except Exception as e:
            print(f"Error loading artifacts: {e}")
            raise

    def preprocess_input(self, data):
        """Preprocess input data to match training format."""
        features = data.drop(columns=['uuid', 'status'], errors='ignore')

        # Check for missing columns (crucial!)
        expected_cols = self.scaler.feature_names_in_
        missing_cols = set(expected_cols) - set(features.columns)
        if missing_cols:
            raise ValueError(f"Missing columns in input data: {missing_cols}")

        features_normalized = self.scaler.transform(features)

        # Reshape to (batch_size, sequence_length, height, width, channels)
        features_reshaped = features_normalized.reshape(-1, self.sequence_length, self.height, self.width, self.channels)
        return features_reshaped

    def predict(self, dataset, n_samples=5, random_state=42):
        """Make predictions on a random subset of the dataset."""
        try:
            random_rows = dataset.sample(n=n_samples, random_state=random_state)
            uuids = random_rows['uuid']
            original_status = random_rows['status']

            n_samples = n_samples

            X_input = self.preprocess_input(random_rows)

            print("Input shape (before prediction):", X_input.shape)  # Very important!

            predictions = self.model.predict(X_input)
            predicted_classes = np.argmax(predictions, axis=1)
            predicted_labels = self.label_encoder.inverse_transform(predicted_classes)

            predictions_df = pd.DataFrame({
                'UUID': uuids,
                'Original Status': original_status,
                'Predicted Status': predicted_labels
            })

            def color_status(status):
                color_map = {'COVID-19': Fore.RED, 'healthy': Fore.GREEN, 'symptomatic': Fore.BLUE}
                return f"{color_map.get(status, '')}{status}{Style.RESET_ALL}"

            predictions_df['Original Status'] = predictions_df['Original Status'].apply(color_status)
            predictions_df['Predicted Status'] = predictions_df['Predicted Status'].apply(color_status)

            accuracy = np.mean(original_status == predicted_labels) * 100

            print("\nPrediction Results:")
            print(tabulate(predictions_df, headers='keys', tablefmt='pretty'))
            print(f"\nNo of samples : {n_samples}")
            print(f"\nBatch Accuracy: {accuracy:.2f}%")

            return predictions_df
        except Exception as e:
            print(f"Error during prediction: {e}")
            return None  # Or handle as needed

# %%
try:
    predictor = CovidPredictorCNNLSTM()
    results = predictor.predict(decorrelated, n_samples=602)
except Exception as e:
    print(f"Error during prediction: {e}")
# Out:
# Model and artifacts loaded successfully.
# Input shape (before prediction): (602, 1, 1, 107, 1)
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
#
# Prediction Results:
# +------+--------------------------------------+-----------------+------------------+
# |      |                 UUID                 | Original Status | Predicted Status |
# +------+--------------------------------------+-----------------+------------------+
# | 2957 | f7bdbe37-e5a7-4ea5-a6c2-6b1c5a066695 |     healthy     |     healthy      |
# | 1650 | 8d870fda-3cb4-4d17-8650-c52596963ff3 |   symptomatic   |   symptomatic    |
# | 3793 | 61f98ca8-54c9-4a7f-90f3-82c1c34ca600 |   symptomatic   |   symptomatic    |
# | 6114 | b3bc167c-616b-47e4-a4ff-95e1d40dfdfd |   symptomatic   |   symptomatic    |
# | 1268 | 8f5531fb-5c2a-450b-b14c-4321085887d8 |    COVID-19     |     COVID-19     |
# | 132  | e16268c9-dc19-43d9-b55b-b01258603ae5 |    COVID-19     |     COVID-19     |
# | 3131 | 029a668c-e4f8-43a9-9166-8259a9894d8f |   symptomatic   |   symptomatic    |
# | 5036 | 72bf1cb5-9f60-40db-9666-470d6d02f02c |     healthy     |   symptomatic    |
# | 1978 | a5aeaa95-ed25-452b-b112-62c042c21b33 |    COVID-19     |   symptomatic    |
# | 5812 | 733b0db4-aec3-4afa-a7fc-7e29e0c9403c |    COVID-19     |     COVID-19     |
# | 534  | 362c55e4-0bb0-4295-9dc3-be1e1e7e95a4 |     healthy     |     healthy      |
# | 1916 | 824a8cf9-1199-48bf-aad5-65539d6d2011 |   symptomatic   |   symptomatic    |
# | 5417 | 0527be95-d7f1-4156-8e37-1587355661ca |     healthy     |     healthy      |
# | 3123 | 0b2f75d7-f116-4f35-ae4c-f2018eab2794 |     healthy     |     healthy      |
# | 4614 | 380e3cbd-961d-42ff-9553-e902926e6740 |   symptomatic   |   symptomatic    |
# | 1163 | bac8326b-2652-443d-8b58-af96cdf5284d |    COVID-19     |     COVID-19     |
# | 3408 | f0da0dd1-a4d1-47ac-bc31-e9c6ceb05e28 |     healthy     |     healthy      |
# | 4558 | 059ae242-fffd-44c7-b821-9d73f93449aa |     healthy     |     healthy      |
# | 2526 | 0f8d80f9-700e-4069-924d-e15f29d7c19a |    COVID-19     |     COVID-19     |
# | 2291 | 1a324acb-12f7-4eef-8e8c-0c71a47280e2 |    COVID-19     |     COVID-19     |
# | 764  | 338ffa66-a7e2-488a-b5a9-d7b808731922 |     healthy     |     healthy      |
# | 5633 | f942b766-ef1e-42e7-826d-40e053414824 |     healthy     |     healthy      |
# | 2795 | bf8e9236-0d63-46ed-9855-38a1074c2121 |     healthy     |     healthy      |
# | 4071 | f5e8d8ec-e234-4117-a4ab-2f7dba0066ef |   symptomatic   |   symptomatic    |
# | 5837 | bb94e3f4-831c-4c04-b528-617cf04ab8c7 |   symptomatic   |   symptomatic    |
# | 2185 | d57d4c31-4f34-41cd-9fdf-84e4df3f2dcc |    COVID-19     |     COVID-19     |
# | 1049 | 4a54513d-cdcf-4ea6-8139-b0f1d33d41d8 |    COVID-19     |     COVID-19     |
# | 2705 | 0abc55f4-83bb-4284-87d2-65044bf06200 |     healthy     |     healthy      |
# | 1805 | 2cc2fd2e-6314-424a-977b-7237f935fb65 |   symptomatic   |   symptomatic    |
# | 2251 | bb9766af-74b9-4533-ac93-e0d75f7bd7ba |   symptomatic   |   symptomatic    |
# | 4672 | 47298691-1737-4d18-b301-b3526e935c1e |     healthy     |     healthy      |
# | 2876 | 82a7bdf0-56fb-426c-9dc6-7811ee82ece2 |   symptomatic   |   symptomatic    |
# | 5911 | 3c6cfda1-3fe9-403d-b5d1-7797420debe2 |    COVID-19     |     COVID-19     |
# | 1485 | 9e41c672-ffbd-4a9b-919b-3fdfd4771f63 |   symptomatic   |   symptomatic    |
# | 2818 | 18736769-dad3-4fa6-88d5-6e8dfc951008 |     healthy     |     healthy      |
# | 2949 | cbbef439-96c8-4dca-b3ff-f8491b7c8653 |   symptomatic   |   symptomatic    |
# | 2268 | d9b4a30f-682d-4889-b65f-b359f4ebc74d |   symptomatic   |   symptomatic    |
# | 3396 | f0da0dd1-a4d1-47ac-bc31-e9c6ceb05e28 |     healthy     |     healthy      |
# | 5435 | a5025365-abca-4ff4-a335-a692389b7553 |    COVID-19     |     COVID-19     |
# | 1740 | 9a80a95e-6d74-4d45-bfd0-62c3eb40471a |   symptomatic   |   symptomatic    |
# | 755  | ea550a6f-3b55-4beb-9aa3-1325feed86ab |    COVID-19     |     healthy      |
# | 6026 | 1da3fe9f-2803-4d66-a43e-6c64bd2aef40 |   symptomatic   |   symptomatic    |
# | 712  | 52f6838a-4033-4a71-84bb-81cbb4e64ab7 |   symptomatic   |   symptomatic    |
# | 6346 | e5309e82-43fc-4aac-9bd7-200c3b4e926d |   symptomatic   |   symptomatic    |
# | 6232 | 2974b8ef-49f1-4390-a974-758104bd9f02 |    COVID-19     |     COVID-19     |
# |  31  | dff83863-6ceb-416a-9846-26b13bab1bfa |   symptomatic   |   symptomatic    |
# | 2316 | b66ea1a8-a46f-4890-8b1f-91c5841bfc99 |   symptomatic   |   symptomatic    |
# | 5715 | 74e63c62-6e52-460e-8057-8552db1799c7 |   symptomatic   |   symptomatic    |
# | 625  | a75adc66-7f70-4f0f-91f7-7a2a2eac61e9 |    COVID-19     |     COVID-19     |
# | 5246 | 70bd76c5-bfc6-4a4d-9942-47588699c714 |   symptomatic   |   symptomatic    |
# | 3226 | 225cf920-b008-43d4-92e3-6640aaddd431 |   symptomatic   |   symptomatic    |
# | 1330 | 1e34e7ac-1799-4880-970f-cf2ae6cbaa98 |     healthy     |     healthy      |
# | 2284 | 046545bc-7f2c-4425-9be2-ffc22bba515e |     healthy     |     healthy      |
# | 1699 | 036d875c-d39b-45f1-a17f-7f7badf0aa42 |   symptomatic   |     COVID-19     |
# | 996  | 09de6967-b295-4516-8a4d-4d95c9a7b02c |   symptomatic   |   symptomatic    |
# | 5962 | a7b2afe9-4067-4ab2-8d9f-1d52008586e5 |     healthy     |     healthy      |
# | 2407 | 03d30b8b-03f8-4089-bda8-0e14deec7d82 |    COVID-19     |     COVID-19     |
# | 3383 | 36d918eb-8f0c-4ab2-a7de-7aa27f58800c |     healthy     |     healthy      |
# | 476  | d446bc98-e79e-41a7-9311-010b43c3f943 |   symptomatic   |   symptomatic    |
# | 6178 | ac822d1e-4d15-4b74-af4c-eacbd77b7f27 |     healthy     |     healthy      |
# | 1918 | 824a8cf9-1199-48bf-aad5-65539d6d2011 |   symptomatic   |   symptomatic    |
# | 3826 | 814a5c9e-6174-4efa-a378-a990ac566ae2 |    COVID-19     |   symptomatic    |
# | 324  | 16527cdc-bf15-4805-8f8d-28b11175ff5d |     healthy     |   symptomatic    |
# | 4092 | eeb42d9f-7fda-44b0-896d-503ee9722216 |     healthy     |     healthy      |
# | 1891 | 218f522f-d3b0-4370-a93f-e8a70d958950 |   symptomatic   |   symptomatic    |
# | 5202 | ada1def9-7e36-4d4e-8e3e-e678afee4185 |   symptomatic   |   symptomatic    |
# | 3615 | 824a8cf9-1199-48bf-aad5-65539d6d2011 |   symptomatic   |   symptomatic    |
# | 4815 | 6811fc15-6ffc-4623-85aa-bf477c4d0082 |   symptomatic   |   symptomatic    |
# | 1886 | a75adc66-7f70-4f0f-91f7-7a2a2eac61e9 |    COVID-19     |     COVID-19     |
# | 3786 | f4e51208-6dcd-46c2-b2f3-f4fa6e6f8760 |    COVID-19     |     COVID-19     |
# | 3204 | 1796e9dd-2cd1-4cce-b17f-f3ca743e54c5 |   symptomatic   |   symptomatic    |
# | 1097 | 24f20435-bf37-4ba8-b5e3-47c492e8f52b |     healthy     |     healthy      |
# | 208  | 2687c6bd-f9cc-43a3-b7f3-d0663cc77e65 |     healthy     |     healthy      |
# | 3933 | 6c9a5f33-9e90-4c08-8782-20b0d86abc46 |   symptomatic   |   symptomatic    |
# | 3554 | 21aee478-6d13-45ea-be4d-4f29fd244798 |    COVID-19     |     COVID-19     |
# | 1183 | 1357788c-fd94-45ff-b31d-da0cda859731 |    COVID-19     |     COVID-19     |
# |  96  | 57e1df06-5e7a-451e-8ffa-6aeaeb732192 |     healthy     |     healthy      |
# | 3311 | d11e501c-6f48-4028-8198-9075c67ce238 |   symptomatic   |   symptomatic    |
# | 2182 | d57d4c31-4f34-41cd-9fdf-84e4df3f2dcc |    COVID-19     |     COVID-19     |
# | 496  | 69101dc9-dfd5-43b5-b063-54a2e634e021 |     healthy     |     healthy      |
# | 4096 | 2cba06c6-a2af-4307-b53b-cdde40ee9492 |   symptomatic   |     healthy      |
# | 3785 | 67b68c39-caf5-46b1-b8da-7f2fd9068a5a |    COVID-19     |     COVID-19     |
# | 3433 | dabd8101-b56b-40cd-84c6-169b7f8c6fbc |   symptomatic   |   symptomatic    |
# | 1038 | 7ff6b5bf-0951-4da4-a35b-8b3187a06aae |     healthy     |     healthy      |
# | 2676 | 72dd3a5a-622a-4f94-aa17-b8142e82a944 |   symptomatic   |   symptomatic    |
# | 6093 | d9b4a30f-682d-4889-b65f-b359f4ebc74d |   symptomatic   |   symptomatic    |
# | 1022 | 9031d3b2-4019-403f-9c71-f387e6b60a82 |    COVID-19     |     COVID-19     |
# | 4600 | 6dff10f3-5df0-4b5a-be62-613afd6115dc |     healthy     |     healthy      |
# | 1075 | 2cc2fd2e-6314-424a-977b-7237f935fb65 |   symptomatic   |   symptomatic    |
# | 3128 | 06b568b5-b9f8-4334-816c-c16009bb5de7 |    COVID-19     |     COVID-19     |
# | 6353 | e5309e82-43fc-4aac-9bd7-200c3b4e926d |   symptomatic   |   symptomatic    |
# | 604  | bb9766af-74b9-4533-ac93-e0d75f7bd7ba |   symptomatic   |   symptomatic    |
# | 2542 | 494fdf0a-fc66-4292-acc4-7a69df02405f |   symptomatic   |     COVID-19     |
# | 2882 | 372846d2-d0b1-435b-bd1c-2580506dc502 |     healthy     |     healthy      |
# | 2163 | ada1def9-7e36-4d4e-8e3e-e678afee4185 |   symptomatic   |   symptomatic    |
# | 5516 | 8be589c2-c09a-442d-a0a0-50094a73f0d5 |   symptomatic   |   symptomatic    |
# |  80  | 6dd2d1e3-e140-489f-905f-007a7f54321c |     healthy     |   symptomatic    |
# | 3347 | aa059172-1850-4afe-8809-2fe79603286a |    COVID-19     |     COVID-19     |
# | 1954 | 0f8fb3e0-1a30-4bd3-982a-24342a0bdc70 |     healthy     |     healthy      |
# | 2225 | 5830e2bb-5a49-4ec2-9b53-9c6727e54e1a |     healthy     |     healthy      |
# | 1002 | 5b5baa97-50c4-4c11-8a60-a2b39c34e56b |   symptomatic   |   symptomatic    |
# | 5979 | 55c0a763-5f42-476e-9c72-e2924b21b2b4 |   symptomatic   |   symptomatic    |
# | 611  | 720409ca-6b1e-4237-9fb8-14e8ddfdcb37 |     healthy     |     healthy      |
# |  23  | b768c79d-32bc-423a-b592-da360cb02ed2 |   symptomatic   |   symptomatic    |
# | 5689 | 03cfc75c-88a0-4ca9-8ca4-4aa61e2dec37 |     healthy     |     healthy      |
# | 4406 | 3050a1e2-d70b-4f86-9e57-f33220b8f990 |    COVID-19     |     COVID-19     |
# | 3245 | 7876c549-066a-4ea1-a82e-45772114f964 |   symptomatic   |   symptomatic    |
# | 6147 | 35ec6e33-eeeb-4734-9a52-c37a949e5443 |   symptomatic   |   symptomatic    |
# | 3475 | bd14922a-f88e-4b99-a338-360789a40b69 |    COVID-19     |     COVID-19     |
# | 4623 | 55c0a763-5f42-476e-9c72-e2924b21b2b4 |   symptomatic   |   symptomatic    |
# | 696  | f0bc6079-5c16-4c95-91be-ddffc7bb37b0 |   symptomatic   |   symptomatic    |
# | 1425 | 6c9a5f33-9e90-4c08-8782-20b0d86abc46 |   symptomatic   |   symptomatic    |
# | 233  | 6ec47745-dc4f-4c8b-8c7e-771e5cd47c33 |     healthy     |     healthy      |
# | 2177 | ada1def9-7e36-4d4e-8e3e-e678afee4185 |   symptomatic   |   symptomatic    |
# | 2077 | 4982b195-822b-4d81-8b0d-d032b6762fdc |   symptomatic   |   symptomatic    |
# | 3782 | 67b68c39-caf5-46b1-b8da-7f2fd9068a5a |    COVID-19     |   symptomatic    |
# | 1129 | d6ee9da5-ff1d-4677-9ab2-da397e3267c4 |   symptomatic   |   symptomatic    |
# | 1652 | 8d870fda-3cb4-4d17-8650-c52596963ff3 |   symptomatic   |   symptomatic    |
# | 3399 | f0da0dd1-a4d1-47ac-bc31-e9c6ceb05e28 |     healthy     |     healthy      |
# | 5544 | 3e6c4fe1-b681-48d7-a576-5c4ddee41c70 |   symptomatic   |   symptomatic    |
# | 5405 | 9e6d88da-2a85-4c86-a606-e66d83bf7550 |     healthy     |     healthy      |
# | 3927 | 6c9a5f33-9e90-4c08-8782-20b0d86abc46 |   symptomatic   |   symptomatic    |
# | 3039 | 8ec67d70-2a82-45ea-a646-ab8a5bc4bf4f |   symptomatic   |   symptomatic    |
# | 239  | 909f7f8b-d304-4238-83b0-de0e4114d3e2 |   symptomatic   |   symptomatic    |
# | 198  | b392ae80-f91a-4a78-bad3-2e8a8c8130d2 |    COVID-19     |     COVID-19     |
# | 2252 | bb9766af-74b9-4533-ac93-e0d75f7bd7ba |   symptomatic   |   symptomatic    |
# | 6250 | dddb1a55-d976-40bc-ad41-cdc713623e03 |   symptomatic   |   symptomatic    |
# | 5216 | ada1def9-7e36-4d4e-8e3e-e678afee4185 |   symptomatic   |   symptomatic    |
# | 3167 | bbb221cc-8c5c-407d-9ae1-ae8ebd842504 |   symptomatic   |   symptomatic    |
# | 3165 | 7a985f89-ed5d-41e2-9f5d-8d8982508665 |    COVID-19     |     COVID-19     |
# | 1580 | e88932d8-8869-4fa2-b4a5-1d4a3ddce94d |   symptomatic   |   symptomatic    |
# | 2276 | d9b4a30f-682d-4889-b65f-b359f4ebc74d |   symptomatic   |   symptomatic    |
# | 465  | ba6f354e-2189-4b93-b037-c07ee2e72f40 |   symptomatic   |   symptomatic    |
# | 346  | 52f6838a-4033-4a71-84bb-81cbb4e64ab7 |   symptomatic   |   symptomatic    |
# | 2880 | 82a7bdf0-56fb-426c-9dc6-7811ee82ece2 |   symptomatic   |   symptomatic    |
# | 6043 | 81a75de7-dc30-4c6b-9722-c238feebf447 |     healthy     |     healthy      |
# | 1074 | 2cc2fd2e-6314-424a-977b-7237f935fb65 |   symptomatic   |   symptomatic    |
# | 4082 | f6b63555-a974-4879-88f7-6302464721a2 |     healthy     |     healthy      |
# | 1559 | bbd87814-fc8c-493a-907c-aeb18acf8e44 |     healthy     |     healthy      |
# | 1905 | 218f522f-d3b0-4370-a93f-e8a70d958950 |   symptomatic   |   symptomatic    |
# | 5740 | 3ad08dbf-1d9e-4055-83fa-9a0e0bb45d34 |   symptomatic   |     healthy      |
# | 5066 | 66636b7b-3e0e-4613-9f1f-4ec16fb313c3 |     healthy     |     healthy      |
# | 2910 | 93d51cf7-6dee-49e5-b434-fa81a7595132 |   symptomatic   |   symptomatic    |
# | 4631 | 55c0a763-5f42-476e-9c72-e2924b21b2b4 |   symptomatic   |   symptomatic    |
# | 6103 | 4c2840ed-fd4b-4a86-b976-5cc040d6ea4e |    COVID-19     |     COVID-19     |
# | 503  | a6645b1d-dadc-4258-b03b-c5b3f05d519d |    COVID-19     |     COVID-19     |
# | 3599 | 552dda14-3fea-4473-b39a-f409eb6a08f7 |     healthy     |     healthy      |
# | 3881 | c6f428ef-5e9e-4ee9-ac88-aa50b5d435ad |   symptomatic   |     healthy      |
# | 2131 | 510640bb-d6db-483f-a754-c5fa1eaaa388 |     healthy     |     healthy      |
# | 3960 | 70ea9638-f7e3-4f16-bb97-7d066a0e6cdf |   symptomatic   |   symptomatic    |
# | 491  | f3ef7d3e-56e1-496b-8a46-b593e33d25d6 |   symptomatic   |     COVID-19     |
# | 5779 | 8396e93f-96ff-4fa3-8ef9-41c4d0ee191e |   symptomatic   |   symptomatic    |
# | 5774 | 8396e93f-96ff-4fa3-8ef9-41c4d0ee191e |   symptomatic   |   symptomatic    |
# | 230  | a41a84b6-f192-4b79-bb08-e47285cf8a4e |    COVID-19     |     COVID-19     |
# | 5755 | c494d05a-a6fa-462e-9d3e-28e91b82147d |   symptomatic   |   symptomatic    |
# | 6217 | 481443c9-17a9-4194-9525-8c5fc2cd15fc |   symptomatic   |   symptomatic    |
# | 2346 | f5a36e3a-28f9-461d-970e-c95ff38f4740 |     healthy     |     healthy      |
# | 1101 | 9821da28-7655-4736-abf8-4c89582e407f |     healthy     |     healthy      |
# | 3213 | 3481b694-34fe-4b03-a529-88ef085815fd |    COVID-19     |     COVID-19     |
# | 263  | 8956ab9c-a0ca-4f2e-ae00-1f5d0065d50b |   symptomatic   |   symptomatic    |
# | 156  | 01614a4a-947f-43ca-a609-fc2787509f6f |   symptomatic   |   symptomatic    |
# | 4325 | 03c8796e-547e-4158-ae5f-7c613aaeb02f |   symptomatic   |   symptomatic    |
# | 5867 | 49c952bf-0654-4baa-a67f-363745f146de |    COVID-19     |     COVID-19     |
# | 3269 | 22ac9dc4-858e-4db5-886e-792d7553e67f |   symptomatic   |   symptomatic    |
# | 1934 | 922fd4da-e8ce-4ef5-b9a8-56921dfa9328 |     healthy     |     healthy      |
# | 805  | 1e2fb96c-cc9c-450d-9474-b363b22adfe8 |     healthy     |     COVID-19     |
# | 2798 | f46c5215-8097-4891-bbd4-d4ac017c224c |   symptomatic   |   symptomatic    |
# | 4984 | 8956ab9c-a0ca-4f2e-ae00-1f5d0065d50b |   symptomatic   |   symptomatic    |
# | 381  | db0a337d-5bfb-41a7-980a-7516a8afb3ab |     healthy     |     COVID-19     |
# | 4697 | 8c8228e5-3ce8-4420-82e6-24d5c54d612d |   symptomatic   |   symptomatic    |
# | 4013 | 80411c72-2727-40a3-a781-0d71f1bb717d |     healthy     |   symptomatic    |
# | 217  | 5be10c89-4c9a-495e-8671-f445f51a3fe0 |   symptomatic   |   symptomatic    |
# | 6003 | 72b95c95-1a95-437c-9d52-86b53461b304 |     healthy     |     COVID-19     |
# | 6099 | bd3f28af-fb51-4867-b4ce-b56a6b17a79b |   symptomatic   |   symptomatic    |
# | 4375 | 167b1c65-40e6-4330-8dc7-d51d735ccdab |   symptomatic   |   symptomatic    |
# | 1520 | 562c3783-d5ac-4d30-90c6-054fbc83dbff |   symptomatic   |   symptomatic    |
# | 4004 | 5e5bbcfe-9901-4fd8-9be7-d51ea7251cbe |   symptomatic   |   symptomatic    |
# | 3767 | 15f12b8d-7ba5-444e-975f-f1b26c6e75ae |    COVID-19     |     healthy      |
# | 4619 | 6f5c9187-db40-4552-abcf-200daef89298 |   symptomatic   |   symptomatic    |
# | 4477 | ee4c059e-fd72-47c6-9814-dc4a2a2f919d |   symptomatic   |   symptomatic    |
# | 1737 | 8905d5ea-2412-4222-93f8-95cd4455f8e4 |     healthy     |     healthy      |
# | 3102 | de543d13-541c-4ad7-bb3c-c5c302de3aaf |     healthy     |     healthy      |
# | 2398 | eeaa9780-b73a-4e0f-b075-4dc5fbb54080 |     healthy     |     healthy      |
# | 2436 | 218f522f-d3b0-4370-a93f-e8a70d958950 |   symptomatic   |   symptomatic    |
# | 3077 | 2ba1edda-3fc6-43f6-91b6-4e5c766425a3 |   symptomatic   |   symptomatic    |
# | 2929 | e56b40e6-935c-41c6-a04f-cfa133d69cec |    COVID-19     |     COVID-19     |
# | 1042 | 4b46da7b-b391-45f6-925a-9aa31eb5b58a |   symptomatic   |   symptomatic    |
# | 3698 | b6cab2e1-4f1c-47e7-91e0-97fb9118d890 |     healthy     |     healthy      |
# | 2473 | 5be10c89-4c9a-495e-8671-f445f51a3fe0 |   symptomatic   |   symptomatic    |
# | 2142 | 341ff20f-b75f-4d5a-8ee9-38ba198ed6ec |     healthy     |     healthy      |
# | 3861 | b4b7f4b3-08b4-46ad-a39f-ff4e5b029520 |     healthy     |     healthy      |
# | 5179 | b60e7ee3-64c2-4982-8212-750b4dbe8c66 |    COVID-19     |     COVID-19     |
# | 6011 | 34747e4f-a116-452d-b611-eefecc0c585e |   symptomatic   |   symptomatic    |
# | 2287 | 731cbe07-5754-46cf-bb5c-873a670cd5d7 |    COVID-19     |     COVID-19     |
# | 1745 | 64522664-f2f7-4141-9b74-ba0b9d181c31 |   symptomatic   |   symptomatic    |
# | 1702 | b7b6a650-3276-43fb-90b1-73134b483fb6 |    COVID-19     |     COVID-19     |
# | 4594 | 86b4b29b-2c0f-40e3-9d37-644b492ea570 |    COVID-19     |     COVID-19     |
# | 743  | c3382b37-9f19-4379-b488-68f636a6c684 |   symptomatic   |   symptomatic    |
# | 4500 | 296446a3-d81c-4aaa-897f-d80c849b95b0 |   symptomatic   |     healthy      |
# | 5427 | 9668aedd-1d7b-48e7-86d1-7c00c67211ae |   symptomatic   |   symptomatic    |
# | 2164 | ada1def9-7e36-4d4e-8e3e-e678afee4185 |   symptomatic   |   symptomatic    |
# | 5089 | 05bb63c1-bff1-4faf-bb2a-b887e7016f69 |     healthy     |     healthy      |
# | 2154 | 7e307ff5-00ca-4f25-bd20-1c1d2d3b9b47 |   symptomatic   |   symptomatic    |
# | 5608 | 2cc2fd2e-6314-424a-977b-7237f935fb65 |   symptomatic   |   symptomatic    |
# | 4382 | fd59bf10-ea8f-4401-a6d9-a9cce4e8303f |   symptomatic   |   symptomatic    |
# | 5451 | b7b6a650-3276-43fb-90b1-73134b483fb6 |    COVID-19     |     COVID-19     |
# | 3075 | 12519d8d-43bb-4ed7-9c76-03d3fb486c4a |   symptomatic   |   symptomatic    |
# | 1729 | b618923d-796d-4adb-ae9e-266ab08f1249 |     healthy     |     healthy      |
# | 3323 | c55e4ac5-03f1-4432-ada6-be2c30e76bcb |    COVID-19     |     COVID-19     |
# | 747  | c3382b37-9f19-4379-b488-68f636a6c684 |   symptomatic   |   symptomatic    |
# | 1623 | 2e4456dd-bb47-45f7-b2ef-7b2d2f2859c6 |     healthy     |     healthy      |
# | 4339 | f3bdd3ab-aac5-42ca-9c3e-36475ee47349 |     healthy     |     healthy      |
# | 3332 | 1ed9491a-4036-4308-bc44-5036fc2e9f28 |     healthy     |     healthy      |
# | 1512 | 36a556ff-6813-48c7-b500-c3787c2d23c3 |   symptomatic   |   symptomatic    |
# | 6077 | fb6e4eac-fba3-4ab4-95ae-53488da9b68b |   symptomatic   |   symptomatic    |
# | 1961 | e247085a-cf34-45be-b3c1-3c609c7d2bf1 |     healthy     |     COVID-19     |
# | 5269 | 105d18a9-f281-4e4c-bb7d-1ad9885696c9 |    COVID-19     |     COVID-19     |
# | 247  | 8a5feabb-3b0a-49b5-900c-6d3d31e96794 |     healthy     |     healthy      |
# | 5497 | 4f6c6fa4-e708-4c9a-ac8a-7137a4a60093 |    COVID-19     |     COVID-19     |
# | 2462 | 64e5b75c-8c2d-4640-920b-734c7e126616 |     healthy     |     healthy      |
# | 401  | b73530b6-f66b-4599-af9a-4066253bae7f |    COVID-19     |     COVID-19     |
# | 1544 | 4ce3137f-941d-4ec5-bb2c-88d1b9fbafa3 |     healthy     |   symptomatic    |
# | 2432 | 218f522f-d3b0-4370-a93f-e8a70d958950 |   symptomatic   |   symptomatic    |
# | 4383 | fd59bf10-ea8f-4401-a6d9-a9cce4e8303f |   symptomatic   |   symptomatic    |
# | 6089 | d9b4a30f-682d-4889-b65f-b359f4ebc74d |   symptomatic   |   symptomatic    |
# | 5377 | 1ed9491a-4036-4308-bc44-5036fc2e9f28 |     healthy     |     healthy      |
# | 3172 | 11c1e2d8-52e2-4e32-8ab8-b858268e0ca9 |     healthy     |     healthy      |
# | 4958 | eceaa3a9-f850-4ba9-82ee-1bcd2575b99c |   symptomatic   |   symptomatic    |
# | 2751 | ae5570c6-766e-4e22-bcd3-a7ab006d5d82 |    COVID-19     |     COVID-19     |
# | 1345 | 48bcd9fe-f974-46cc-910a-1b0307eaa336 |   symptomatic   |   symptomatic    |
# | 4141 | 90df4728-8750-4646-a0a4-027f2c9cd544 |   symptomatic   |   symptomatic    |
# | 957  | 456005c3-f550-4770-a091-befce2a7d630 |   symptomatic   |   symptomatic    |
# | 1375 | 44276123-82cf-4aa0-abb6-a483c83b9852 |     healthy     |     COVID-19     |
# | 5944 | ea14fc20-28a3-4cb1-aaa6-c7081ba3dd29 |   symptomatic   |   symptomatic    |
# | 1371 | f2574f9d-beae-4a85-ad18-289a400e1b6a |     healthy     |     healthy      |
# |  88  | 87abbea8-6765-4487-b95b-0eae7ef46271 |   symptomatic   |   symptomatic    |
# | 1554 | e43f8cad-6593-4258-b428-16671808e8d2 |     healthy     |     healthy      |
# | 469  | 19654d11-2cef-46ec-8007-4a4c7bea60af |   symptomatic   |   symptomatic    |
# | 1454 | 42ee475c-2a4b-48f0-b33e-9a5f57000770 |   symptomatic   |   symptomatic    |
# | 1509 | 36a556ff-6813-48c7-b500-c3787c2d23c3 |   symptomatic   |   symptomatic    |
# | 4541 | 93711a18-72ba-4e31-a846-73e3baf84128 |   symptomatic   |   symptomatic    |
# | 6045 | 81a75de7-dc30-4c6b-9722-c238feebf447 |     healthy     |     healthy      |
# | 4359 | adaff9bb-1718-48b0-b376-2403b4603fa7 |    COVID-19     |   symptomatic    |
# | 2345 | b09a9f07-62d0-44fa-b3da-b4716361eb88 |   symptomatic   |   symptomatic    |
# | 4928 | e6b481ff-0920-4d48-bb9d-8b5349c483b7 |     healthy     |     healthy      |
# | 1219 | 824a8cf9-1199-48bf-aad5-65539d6d2011 |   symptomatic   |   symptomatic    |
# | 4280 | b5ec57dd-28bb-428d-a420-6617f7749a9a |   symptomatic   |   symptomatic    |
# | 4466 | be0fe831-c469-4a13-961f-e3bd6dda0633 |   symptomatic   |     healthy      |
# | 4358 | adaff9bb-1718-48b0-b376-2403b4603fa7 |    COVID-19     |     COVID-19     |
# | 6309 | e614bfdf-0264-4094-8585-a1cd4068f503 |     healthy     |     healthy      |
# | 3265 | 20fd26c4-26d2-48d8-bf6f-f5b37a0d838c |   symptomatic   |     healthy      |
# | 2842 | c91409af-d36d-4ec3-a26d-ba640c97c90c |    COVID-19     |     COVID-19     |
# | 6269 | 453a2e23-38b2-4b65-a2d8-0e89ec37c872 |   symptomatic   |   symptomatic    |
# | 2654 | aa345328-b50f-4bf8-9a8d-cf0063b04e6b |    COVID-19     |     COVID-19     |
# | 351  | 13606b20-6081-484b-93e2-dd80648bfe06 |     healthy     |     healthy      |
# | 5250 | 81e0894b-e409-446a-a891-8aab6d385259 |   symptomatic   |   symptomatic    |
# | 3355 | 7630638c-1d22-4852-be07-5a27af3c1e49 |   symptomatic   |   symptomatic    |
# | 811  | 353bb06f-a51c-4646-b890-d7fd3529e0e2 |     healthy     |     healthy      |
# | 4775 | 49cc8b94-838b-4b23-9fb1-8d9384520634 |   symptomatic   |   symptomatic    |
# | 4772 | 49cc8b94-838b-4b23-9fb1-8d9384520634 |   symptomatic   |   symptomatic    |
# | 4956 | d93b74aa-faed-4737-9d5e-540e0fbdb961 |     healthy     |     healthy      |
# | 3534 | 31e5a9cf-6a3e-43a3-8e0f-65c99f5748e9 |    COVID-19     |     COVID-19     |
# | 4275 | f64f33a5-b6e1-4d5c-ab1b-8d48dd826440 |    COVID-19     |     COVID-19     |
# | 1545 | 4ce3137f-941d-4ec5-bb2c-88d1b9fbafa3 |     healthy     |     healthy      |
# | 2596 | f3abf042-e22d-4e27-af5b-6650cc8f4883 |     healthy     |     healthy      |
# | 5326 | 637d6498-1d52-4860-9976-5a7a94f2a0c3 |    COVID-19     |     COVID-19     |
# | 2902 | 39fc7508-62ba-41f5-ba87-fbb328b61101 |   symptomatic   |   symptomatic    |
# | 4932 | f9b7c88c-63c0-489e-80c7-75ac6b11c182 |     healthy     |     healthy      |
# | 2669 | 620ded24-220f-4ada-b032-2b5c170b279a |    COVID-19     |     COVID-19     |
# | 296  | f942b766-ef1e-42e7-826d-40e053414824 |     healthy     |     healthy      |
# | 1108 | 9821da28-7655-4736-abf8-4c89582e407f |     healthy     |     healthy      |
# | 5672 | c2e033f0-5e2f-4793-be75-afa9ae7d3f8f |     healthy     |     healthy      |
# |  37  | 7e4d25bb-043f-4314-81ce-c0108df735a1 |   symptomatic   |   symptomatic    |
# | 4532 | 2cbe1acd-2fa9-4726-8ae0-120ddfdb8133 |   symptomatic   |   symptomatic    |
# | 1005 | 977592cb-c1f2-4b5e-bad1-6132b5cd2ad0 |     healthy     |     healthy      |
# | 705  | 4f51059b-0e34-4ae8-8ea8-66630d9b147b |    COVID-19     |     COVID-19     |
# | 2415 | 93d36f3e-2008-44cc-af6f-adb012cef434 |     healthy     |     healthy      |
# | 1869 | 21aee478-6d13-45ea-be4d-4f29fd244798 |    COVID-19     |     COVID-19     |
# | 4260 | e31980dd-7946-467c-9b10-3141c29843b3 |   symptomatic   |   symptomatic    |
# | 3353 | 7630638c-1d22-4852-be07-5a27af3c1e49 |   symptomatic   |   symptomatic    |
# | 5912 | 3c6cfda1-3fe9-403d-b5d1-7797420debe2 |    COVID-19     |     COVID-19     |
# | 2029 | 1dd3b212-e969-4ede-a9d9-f24b711e2028 |    COVID-19     |     COVID-19     |
# | 3149 | e5e07345-f99d-4051-a5be-ec195c931772 |     healthy     |     healthy      |
# | 5456 | b7b6a650-3276-43fb-90b1-73134b483fb6 |    COVID-19     |     COVID-19     |
# | 5457 | b7b6a650-3276-43fb-90b1-73134b483fb6 |    COVID-19     |     COVID-19     |
# | 6252 | b8d76cc3-378a-4ac6-9aef-0640c8473e7e |   symptomatic   |   symptomatic    |
# | 4930 | f9b7c88c-63c0-489e-80c7-75ac6b11c182 |     healthy     |     healthy      |
# | 994  | 09de6967-b295-4516-8a4d-4d95c9a7b02c |   symptomatic   |   symptomatic    |
# | 5412 | 28de837b-8dbf-43a8-a90f-04e644a04933 |     healthy     |     healthy      |
# | 4861 | b618923d-796d-4adb-ae9e-266ab08f1249 |     healthy     |     healthy      |
# | 5385 | eb5db267-0123-403a-99da-2ce15429f502 |   symptomatic   |   symptomatic    |
# | 3238 | 69317fad-cc19-43fe-8537-782fc415ee7c |   symptomatic   |   symptomatic    |
# | 6319 | 2bb66cf8-ae01-4f8d-93d2-3bc4b08c08f8 |     healthy     |     healthy      |
# | 4479 | ee4c059e-fd72-47c6-9814-dc4a2a2f919d |   symptomatic   |   symptomatic    |
# | 511  | e18efb30-aea1-4cf9-aadb-0afe4c51c7df |    COVID-19     |   symptomatic    |
# | 5443 | 0f8fb3e0-1a30-4bd3-982a-24342a0bdc70 |     healthy     |     healthy      |
# | 2445 | b48cf8a8-5988-40ec-a036-198d093d13a4 |     healthy     |     healthy      |
# | 3559 | 87cd6f31-1776-4344-a010-59e39c392968 |   symptomatic   |   symptomatic    |
# | 3244 | 7876c549-066a-4ea1-a82e-45772114f964 |   symptomatic   |   symptomatic    |
# | 4053 | c941e62c-e260-4ee9-959e-af91663ac58c |    COVID-19     |     COVID-19     |
# | 4335 | 255387fa-5934-4b9b-8c6d-9de47c3841b0 |     healthy     |   symptomatic    |
# | 5185 | 31b8dc8d-3fbd-4e0c-bbae-def12bc16ea2 |    COVID-19     |   symptomatic    |
# | 157  | 01614a4a-947f-43ca-a609-fc2787509f6f |   symptomatic   |   symptomatic    |
# | 1765 | 09e64861-61b1-4f66-a7c0-17ac1a0c60f0 |   symptomatic   |   symptomatic    |
# | 4917 | 0db7625d-01c1-4b73-9879-c5609838c746 |     healthy     |     healthy      |
# | 1297 | ea14fc20-28a3-4cb1-aaa6-c7081ba3dd29 |   symptomatic   |   symptomatic    |
# | 1921 | 824a8cf9-1199-48bf-aad5-65539d6d2011 |   symptomatic   |   symptomatic    |
# | 2388 | ccdb32af-58f4-4718-9f6e-eec7e0020382 |    COVID-19     |     COVID-19     |
# | 4638 | 3278e364-afdd-4c39-9126-b8b4a4caf1c5 |     healthy     |     healthy      |
# | 4343 | 008ba489-31ad-44d8-856b-fcf72369dc46 |     healthy     |     healthy      |
# | 5641 | 228b8f67-e43d-4ed3-80ab-7695baa48107 |     healthy     |     healthy      |
# | 4105 | bcf8e484-3423-4654-83e5-8188ef14e73f |     healthy     |     healthy      |
# | 5282 | 637d6498-1d52-4860-9976-5a7a94f2a0c3 |    COVID-19     |     COVID-19     |
# | 2633 | 6352a786-97a0-4d0a-9dcd-5c68c8effb9b |    COVID-19     |     COVID-19     |
# | 1034 | ef4098b8-f694-4b16-89df-c81df3ce4192 |     healthy     |     healthy      |
# | 6414 | 28648464-a8cd-4d33-b861-9c592154a844 |     healthy     |     healthy      |
# | 5121 | e9761e7d-92fa-4307-9fe0-e4efe9c91e0c |   symptomatic   |   symptomatic    |
# | 5492 | 96d74d27-92ff-4886-b3a4-14e2d7886bfe |   symptomatic   |   symptomatic    |
# | 5101 | d85118e0-5f00-4ca3-b56b-94a7b7cd01ee |   symptomatic   |   symptomatic    |
# | 4377 | 167b1c65-40e6-4330-8dc7-d51d735ccdab |   symptomatic   |   symptomatic    |
# | 4817 | 7ec311f3-c48a-4b46-81dd-de4ffca3610c |   symptomatic   |   symptomatic    |
# | 468  | 19654d11-2cef-46ec-8007-4a4c7bea60af |   symptomatic   |   symptomatic    |
# |  79  | 9b1454f3-7e95-4b04-9369-ba923145c84c |   symptomatic   |   symptomatic    |
# | 167  | 69317fad-cc19-43fe-8537-782fc415ee7c |   symptomatic   |   symptomatic    |
# | 5307 | 98fb6294-d339-4c83-8ff5-2bbcf82e35e0 |     healthy     |     healthy      |
# | 1406 | cba605e5-ddfc-498a-afee-4c8fc964863d |   symptomatic   |   symptomatic    |
# | 6091 | d9b4a30f-682d-4889-b65f-b359f4ebc74d |   symptomatic   |   symptomatic    |
# | 4886 | bd132860-47c0-4ada-ab34-fa8b6b551685 |   symptomatic   |   symptomatic    |
# | 1354 | 50e4574d-0fa7-4fa0-977d-394644797b1b |    COVID-19     |     healthy      |
# | 2942 | 7717442d-d687-4821-a55f-a89b524ff17b |   symptomatic   |   symptomatic    |
# | 535  | 164ff16d-2af8-4724-9a57-3b3bd7e17839 |   symptomatic   |   symptomatic    |
# | 1393 | abbff660-5d13-4c31-b842-bbf2189ff14e |    COVID-19     |     COVID-19     |
# | 4576 | e9650512-35f6-4872-acca-c8aca7cd228b |   symptomatic   |   symptomatic    |
# | 5331 | b6589fee-434e-4d2b-9234-f94545322f47 |    COVID-19     |     COVID-19     |
# | 3751 | d009cf2d-59a1-4e33-8071-22f5018bd098 |     healthy     |     healthy      |
# | 4055 | c941e62c-e260-4ee9-959e-af91663ac58c |    COVID-19     |     COVID-19     |
# | 4649 | 617658ed-22f1-4286-9da8-ae3410da15ed |     healthy     |     healthy      |
# | 3296 | 2e4456dd-bb47-45f7-b2ef-7b2d2f2859c6 |     healthy     |     healthy      |
# | 2303 | 244d35b5-565c-4a3b-a1bd-baa8f899f9d2 |   symptomatic   |   symptomatic    |
# | 2890 | bae0c88f-852c-4f3f-8141-d037c777459e |    COVID-19     |     COVID-19     |
# | 4710 | 76682a59-1c14-44e8-93b9-f9f5f774e897 |   symptomatic   |   symptomatic    |
# |  50  | a4ca8568-dcc2-457a-9087-9342c5bb4a62 |   symptomatic   |   symptomatic    |
# | 706  | 4f51059b-0e34-4ae8-8ea8-66630d9b147b |    COVID-19     |     COVID-19     |
# | 3016 | 620ded24-220f-4ada-b032-2b5c170b279a |    COVID-19     |     COVID-19     |
# | 3765 | 589f9a32-571c-42d3-8b4a-92ca39895658 |     healthy     |     healthy      |
# | 2932 | e56b40e6-935c-41c6-a04f-cfa133d69cec |    COVID-19     |     COVID-19     |
# | 4585 | 89c97828-25b3-4957-8f2c-8da426e68d74 |     healthy     |     healthy      |
# | 1433 | 6c9a5f33-9e90-4c08-8782-20b0d86abc46 |   symptomatic   |   symptomatic    |
# | 3752 | d009cf2d-59a1-4e33-8071-22f5018bd098 |     healthy     |     healthy      |
# | 308  | f942b766-ef1e-42e7-826d-40e053414824 |     healthy     |     healthy      |
# | 2952 | 3a36b31d-a87c-48af-8492-d019103b62c2 |   symptomatic   |   symptomatic    |
# | 2118 | 885278b4-30ed-4dd7-a813-f0e2706a12ba |     healthy     |     healthy      |
# | 544  | 91678983-1d96-4390-8f09-55df6a75bb36 |    COVID-19     |     COVID-19     |
# | 4414 | cd70f9b7-5ea5-403c-aff7-4804663bfbf6 |   symptomatic   |   symptomatic    |
# | 4519 | 0ed0f24e-8e57-4183-9b9f-837a701f87df |     healthy     |     healthy      |
# | 2199 | 812a0f06-9e05-459e-84fc-2654bbb8bf9c |    COVID-19     |     COVID-19     |
# | 2997 | 285e7f6f-503a-41f0-ac3b-173433a8cf40 |    COVID-19     |     COVID-19     |
# | 1244 | 092d10af-b848-473c-8dfd-19376b7c587a |   symptomatic   |   symptomatic    |
# | 2886 | a40dc9a5-b433-451e-9adc-ca98a84cc1ef |    COVID-19     |     COVID-19     |
# | 3817 | bf566ad4-6971-48cb-9b99-bbacf1b69438 |   symptomatic   |   symptomatic    |
# | 561  | b618923d-796d-4adb-ae9e-266ab08f1249 |     healthy     |     healthy      |
# | 2787 | 778c38b9-431e-467c-85b0-468e79deacd8 |    COVID-19     |     COVID-19     |
# | 2298 | 922fd4da-e8ce-4ef5-b9a8-56921dfa9328 |     healthy     |     healthy      |
# | 5424 | e92ed6f0-70a8-425f-8dee-1b0443381224 |    COVID-19     |     COVID-19     |
# | 5364 | 355ad6ec-33b2-45ec-a4b1-fa2e7f3cfc6e |   symptomatic   |   symptomatic    |
# | 393  | b73530b6-f66b-4599-af9a-4066253bae7f |    COVID-19     |     COVID-19     |
# | 1153 | c3382b37-9f19-4379-b488-68f636a6c684 |   symptomatic   |   symptomatic    |
# | 3402 | f0da0dd1-a4d1-47ac-bc31-e9c6ceb05e28 |     healthy     |     healthy      |
# |  93  | 57e1df06-5e7a-451e-8ffa-6aeaeb732192 |     healthy     |     healthy      |
# | 864  | 3c903e81-9634-4d62-90f0-f09b95f382f7 |   symptomatic   |   symptomatic    |
# | 5628 | f942b766-ef1e-42e7-826d-40e053414824 |     healthy     |     healthy      |
# | 5044 | f67d8450-f76e-4c47-bbbe-85418e320acb |    COVID-19     |     COVID-19     |
# | 248  | be482d71-4ab2-453d-abd8-e1a7fdeedb06 |     healthy     |     healthy      |
# | 3007 | 620ded24-220f-4ada-b032-2b5c170b279a |    COVID-19     |     COVID-19     |
# | 4570 | 729d23d1-9abd-44df-8b05-22217b1ffbdf |    COVID-19     |     COVID-19     |
# | 1859 | 5aa4dae0-fe23-4eb2-9d62-e6016a1c9f8a |    COVID-19     |     COVID-19     |
# | 4236 | f0da0dd1-a4d1-47ac-bc31-e9c6ceb05e28 |     healthy     |     healthy      |
# | 3006 | 620ded24-220f-4ada-b032-2b5c170b279a |    COVID-19     |     COVID-19     |
# | 4196 | 57263117-e5ef-4d4c-b678-cec8095c7e0d |   symptomatic   |   symptomatic    |
# | 828  | c1371e45-804a-42fc-a3f9-5e66d4dc0a23 |     healthy     |     healthy      |
# | 622  | a75adc66-7f70-4f0f-91f7-7a2a2eac61e9 |    COVID-19     |     COVID-19     |
# | 3994 | 4b89c5e2-1902-4497-af7a-1eda2630656b |    COVID-19     |     COVID-19     |
# | 3078 | 0f79324e-9dc6-4f6c-8c13-2a3041f044d1 |   symptomatic   |   symptomatic    |
# |  91  | 57e1df06-5e7a-451e-8ffa-6aeaeb732192 |     healthy     |   symptomatic    |
# | 318  | 1add9b29-ef49-4a03-b38f-c9391161e7bf |     healthy     |     healthy      |
# | 3121 | 1d146112-7784-4213-ad55-4a276c37fcb6 |   symptomatic   |   symptomatic    |
# | 3717 | 914cd0fc-3623-4424-bc67-759743a0c593 |     healthy     |     healthy      |
# | 6086 | d9b4a30f-682d-4889-b65f-b359f4ebc74d |   symptomatic   |   symptomatic    |
# | 5820 | f504d41c-13e5-4d7a-9a91-0436aab969cf |     healthy     |     healthy      |
# | 2417 | 65be7822-e7c7-4fdc-9549-bf3fac30f919 |    COVID-19     |     COVID-19     |
# | 2617 | f67d8450-f76e-4c47-bbbe-85418e320acb |    COVID-19     |     COVID-19     |
# | 730  | 52f6838a-4033-4a71-84bb-81cbb4e64ab7 |   symptomatic   |   symptomatic    |
# |  17  | 56994aa1-4626-4782-9f27-f125adfd120a |    COVID-19     |     COVID-19     |
# | 6404 | 1c8853d4-5a0b-425e-b211-d20b2d16e35d |    COVID-19     |     COVID-19     |
# | 1786 | 336b15df-b282-4956-bb68-548ec950bb2f |    COVID-19     |     COVID-19     |
# | 3551 | 21aee478-6d13-45ea-be4d-4f29fd244798 |    COVID-19     |     COVID-19     |
# | 2471 | 5be10c89-4c9a-495e-8671-f445f51a3fe0 |   symptomatic   |   symptomatic    |
# | 3196 | 310167e5-7156-46a6-80b2-2a14ec7dff52 |     healthy     |     healthy      |
# | 5964 | 35811251-f9e5-49e9-8ee9-d4ca1afa08f8 |   symptomatic   |   symptomatic    |
# | 3686 | c5901b26-cf9f-4235-be9b-8b900cc77a8b |   symptomatic   |   symptomatic    |
# | 5559 | 6793221c-3716-4cbb-9eb0-58afe524e8b8 |     healthy     |     healthy      |
# | 4657 | b66ea1a8-a46f-4890-8b1f-91c5841bfc99 |   symptomatic   |   symptomatic    |
# | 5227 | 7584c35c-e038-4baf-a57b-c9d824563481 |     healthy     |     healthy      |
# | 1566 | 5542e025-cec0-48d8-8ac2-541975793b94 |   symptomatic   |     healthy      |
# | 5057 | ccdb32af-58f4-4718-9f6e-eec7e0020382 |    COVID-19     |     COVID-19     |
# | 3984 | 01820f7c-b953-4faf-aa13-978cfda6b08e |    COVID-19     |     COVID-19     |
# | 6083 | d9b4a30f-682d-4889-b65f-b359f4ebc74d |   symptomatic   |   symptomatic    |
# | 5019 | 8a7a47d9-7bcc-4eb2-9b93-bf2bf0eccba8 |   symptomatic   |   symptomatic    |
# | 3838 | 09115490-33a9-461c-9437-d7f71be057b0 |    COVID-19     |     COVID-19     |
# | 5832 | 5b7312df-3d0b-4a64-8884-e9072acceb41 |     healthy     |     healthy      |
# | 6300 | 26abd7b6-569b-41ed-955e-0481ed0368dd |   symptomatic   |   symptomatic    |
# | 1090 | 3e1be8df-6634-44ef-b0a1-a4ab499f2959 |     healthy     |     healthy      |
# | 3612 | 824a8cf9-1199-48bf-aad5-65539d6d2011 |   symptomatic   |   symptomatic    |
# | 5218 | 93dfe86e-d139-4b0e-b959-3b210701bab1 |   symptomatic   |   symptomatic    |
# | 4274 | 89a9d33a-38ac-4927-914b-79d448519c72 |     healthy     |     healthy      |
# | 4442 | d5a1411d-d312-44b1-a37d-a387ec13df1a |    COVID-19     |     COVID-19     |
# | 5604 | 8dbfd6be-5252-4201-9480-cf8464a7c2ec |     healthy     |     healthy      |
# |  14  | 56994aa1-4626-4782-9f27-f125adfd120a |    COVID-19     |     COVID-19     |
# | 4333 | 255387fa-5934-4b9b-8c6d-9de47c3841b0 |     healthy     |     healthy      |
# | 5999 | 21aee478-6d13-45ea-be4d-4f29fd244798 |    COVID-19     |     COVID-19     |
# | 3464 | 55c0a763-5f42-476e-9c72-e2924b21b2b4 |   symptomatic   |   symptomatic    |
# | 3869 | 2519f0bc-6606-4537-acc2-b8fdec0ee15c |     healthy     |     healthy      |
# | 6298 | 26abd7b6-569b-41ed-955e-0481ed0368dd |   symptomatic   |   symptomatic    |
# | 6295 | c3382b37-9f19-4379-b488-68f636a6c684 |   symptomatic   |   symptomatic    |
# | 2110 | 7078c585-556f-4e63-8e4f-f82519cf70c1 |   symptomatic   |   symptomatic    |
# | 2641 | f942b766-ef1e-42e7-826d-40e053414824 |     healthy     |     healthy      |
# | 4786 | 3951f2b6-88a3-4419-a191-774fb50b918f |   symptomatic   |     COVID-19     |
# | 1144 | 16b16ff5-e875-4f0f-ad76-bd7ba27faca6 |   symptomatic   |   symptomatic    |
# | 5545 | 3e6c4fe1-b681-48d7-a576-5c4ddee41c70 |   symptomatic   |   symptomatic    |
# | 3107 | de543d13-541c-4ad7-bb3c-c5c302de3aaf |     healthy     |     healthy      |
# | 472  | d2a55629-24e2-4460-8a0a-b7065927ee07 |    COVID-19     |     COVID-19     |
# | 4119 | ea14fc20-28a3-4cb1-aaa6-c7081ba3dd29 |   symptomatic   |   symptomatic    |
# | 1057 | f63fdfe6-071c-480e-bbdb-85cc44accd49 |     healthy     |     healthy      |
# | 4897 | 909bfdb4-9bf0-44e0-a468-d55d03f16a71 |     healthy     |     healthy      |
# | 1832 | 639c6225-edd2-4f9c-8c7f-5fedd57ef73f |    COVID-19     |     COVID-19     |
# | 2375 | 062c3a7f-a783-4b43-806e-6db83aa0da15 |   symptomatic   |   symptomatic    |
# | 1871 | 21aee478-6d13-45ea-be4d-4f29fd244798 |    COVID-19     |     COVID-19     |
# | 4327 | 03c8796e-547e-4158-ae5f-7c613aaeb02f |   symptomatic   |   symptomatic    |
# | 5736 | dcd6359c-4fbc-44ea-93b0-f1da55eb3a75 |     healthy     |     healthy      |
# | 4999 | 8956ab9c-a0ca-4f2e-ae00-1f5d0065d50b |   symptomatic   |   symptomatic    |
# | 1405 | cba605e5-ddfc-498a-afee-4c8fc964863d |   symptomatic   |   symptomatic    |
# | 1477 | e4ec845a-b80b-409b-afa0-81abc3ae3dc7 |    COVID-19     |   symptomatic    |
# | 5251 | 81e0894b-e409-446a-a891-8aab6d385259 |   symptomatic   |   symptomatic    |
# | 756  | ea550a6f-3b55-4beb-9aa3-1325feed86ab |    COVID-19     |   symptomatic    |
# | 5418 | 0527be95-d7f1-4156-8e37-1587355661ca |     healthy     |     healthy      |
# | 6392 | 9ecb18ca-483d-400f-a049-1a078a483c50 |   symptomatic   |     COVID-19     |
# | 3539 | 31e5a9cf-6a3e-43a3-8e0f-65c99f5748e9 |    COVID-19     |     COVID-19     |
# | 3516 | de543d13-541c-4ad7-bb3c-c5c302de3aaf |     healthy     |     healthy      |
# | 265  | 8956ab9c-a0ca-4f2e-ae00-1f5d0065d50b |   symptomatic   |   symptomatic    |
# | 982  | 4260e6fd-0a12-48de-9bfd-1b8644c2186b |     healthy     |     healthy      |
# | 1483 | c4393c6c-412f-4f55-b417-9325337295c1 |   symptomatic   |   symptomatic    |
# | 2716 | cbdd4f1b-a67e-46e3-8f1a-a52da5689294 |   symptomatic   |   symptomatic    |
# | 5064 | 66636b7b-3e0e-4613-9f1f-4ec16fb313c3 |     healthy     |     healthy      |
# | 4700 | 8b733837-961a-4f17-a18c-13b89b54ef69 |    COVID-19     |     COVID-19     |
# | 3774 | 159c098b-ec97-45cf-aeb7-ff389a98d95c |     healthy     |     healthy      |
# | 6423 | f23ee4be-d96c-43ff-a06c-99e1050b7ffe |     healthy     |     healthy      |
# | 4819 | 7ec311f3-c48a-4b46-81dd-de4ffca3610c |   symptomatic   |   symptomatic    |
# | 5062 | 66636b7b-3e0e-4613-9f1f-4ec16fb313c3 |     healthy     |     healthy      |
# | 2157 | 21d95211-da92-44a9-83c7-30f8d4c6d670 |    COVID-19     |     COVID-19     |
# | 2271 | d9b4a30f-682d-4889-b65f-b359f4ebc74d |   symptomatic   |   symptomatic    |
# | 1501 | bb9766af-74b9-4533-ac93-e0d75f7bd7ba |   symptomatic   |   symptomatic    |
# | 763  | 8fc1ec0d-4d46-4a76-a833-68763de21df1 |    COVID-19     |     COVID-19     |
# | 196  | b392ae80-f91a-4a78-bad3-2e8a8c8130d2 |    COVID-19     |     COVID-19     |
# | 4166 | ee899936-5701-4a8f-a3ab-f3292554a148 |    COVID-19     |   symptomatic    |
# | 2765 | 314cd5c3-0030-4ea1-83b3-d6845897b903 |   symptomatic   |   symptomatic    |
# | 3650 | 00eead73-a2c2-480d-b2ee-d79b1a526871 |     healthy     |     healthy      |
# | 5220 | 96fd8500-a077-4d0a-bcd4-d6d5f747c2da |   symptomatic   |   symptomatic    |
# | 2004 | ff1234d7-7837-4ba7-842f-99fdc916baa9 |   symptomatic   |   symptomatic    |
# | 2788 | 778c38b9-431e-467c-85b0-468e79deacd8 |    COVID-19     |     COVID-19     |
# | 3395 | 0ef3c0bc-56c3-44da-bea0-dc31a158414a |    COVID-19     |   symptomatic    |
# | 432  | 498d64dc-e551-4fe1-8da3-ba533134d950 |   symptomatic   |   symptomatic    |
# | 5253 | 8a3058b7-c1ec-43d8-ae17-f1c72da07a21 |     healthy     |     healthy      |
# | 1657 | b2c1d6e5-37e4-45c9-95bd-109c519ebe2f |   symptomatic   |   symptomatic    |
# | 2167 | ada1def9-7e36-4d4e-8e3e-e678afee4185 |   symptomatic   |   symptomatic    |
# | 2370 | ec041149-b613-4b8b-823e-1bed1d6dc6e0 |     healthy     |     healthy      |
# | 2104 | 92a40891-fb6b-41ad-b005-bd84c48d12ef |     healthy     |     healthy      |
# | 2571 | 218f522f-d3b0-4370-a93f-e8a70d958950 |   symptomatic   |   symptomatic    |
# | 1550 | e43f8cad-6593-4258-b428-16671808e8d2 |     healthy     |     healthy      |
# | 5733 | 28c08126-f32e-4337-b4b1-cba26602f185 |   symptomatic   |   symptomatic    |
# | 5067 | ea80b502-dd8c-45bd-b7d5-047a9ab88be3 |     healthy     |     healthy      |
# | 3299 | d3669a39-488f-41fa-8c31-3cd7d1908708 |    COVID-19     |     COVID-19     |
# | 5205 | ada1def9-7e36-4d4e-8e3e-e678afee4185 |   symptomatic   |   symptomatic    |
# |  84  | 6dd2d1e3-e140-489f-905f-007a7f54321c |     healthy     |     COVID-19     |
# | 3849 | 8b65a198-2b0f-452c-ac15-47d892676fc3 |   symptomatic   |   symptomatic    |
# | 2264 | 22002ad7-3fb5-47d7-8987-e3cdc0931439 |   symptomatic   |   symptomatic    |
# | 425  | 7f58cd54-3414-4b3d-a418-8438d549df31 |   symptomatic   |   symptomatic    |
# | 4258 | e31980dd-7946-467c-9b10-3141c29843b3 |   symptomatic   |   symptomatic    |
# | 6328 | 421d9f99-9d55-40e6-8d30-0d9891605994 |     healthy     |     healthy      |
# | 1789 | 336b15df-b282-4956-bb68-548ec950bb2f |    COVID-19     |     COVID-19     |
# | 6337 | 4fccf60b-0beb-47bf-8e36-73f53813d924 |   symptomatic   |   symptomatic    |
# | 5090 | 05bb63c1-bff1-4faf-bb2a-b887e7016f69 |     healthy     |     healthy      |
# | 1323 | 80cb70ea-369c-44aa-b304-b72b5fe3d07b |   symptomatic   |   symptomatic    |
# | 6145 | bfb9c86e-eead-44ac-8969-ea42e869a3a3 |    COVID-19     |     COVID-19     |
# | 4376 | 167b1c65-40e6-4330-8dc7-d51d735ccdab |   symptomatic   |   symptomatic    |
# | 5723 | 28b30c43-8b77-436a-a181-9b36ec9f0553 |     healthy     |     healthy      |
# | 5670 | c2e033f0-5e2f-4793-be75-afa9ae7d3f8f |     healthy     |     healthy      |
# | 4283 | 34191fb6-7fb8-4cbf-a5cf-ea458bf4107b |     healthy     |     healthy      |
# | 378  | db0a337d-5bfb-41a7-980a-7516a8afb3ab |     healthy     |   symptomatic    |
# | 1782 | ed19d797-397f-4218-8412-14d7f5c25780 |    COVID-19     |     COVID-19     |
# | 2862 | f3f25a4e-536f-4fe4-b038-7428fc916411 |   symptomatic   |   symptomatic    |
# | 4113 | ea14fc20-28a3-4cb1-aaa6-c7081ba3dd29 |   symptomatic   |   symptomatic    |
# | 4250 | 6fe32e9d-c238-4cec-bc0d-215300d55bef |   symptomatic   |   symptomatic    |
# | 932  | 78bba857-d1c8-4a56-86d5-650911bad154 |   symptomatic   |     COVID-19     |
# | 3879 | 0dcae895-e7c6-4e47-a399-29f22b37e075 |     healthy     |     healthy      |
# | 4952 | a1182546-5e99-4ba4-b941-351c79866173 |   symptomatic   |   symptomatic    |
# | 185  | 332ab58f-9728-4cea-9960-c49151120510 |    COVID-19     |     COVID-19     |
# | 2698 | c941e62c-e260-4ee9-959e-af91663ac58c |    COVID-19     |     COVID-19     |
# | 4704 | 8b733837-961a-4f17-a18c-13b89b54ef69 |    COVID-19     |     COVID-19     |
# | 1617 | 9333c624-ef59-44f6-9643-fa9b2485c173 |   symptomatic   |   symptomatic    |
# | 1760 | 30a6ca1c-0b72-4ad2-9226-e9bb06add48d |     healthy     |     healthy      |
# | 683  | bcf8e484-3423-4654-83e5-8188ef14e73f |     healthy     |     healthy      |
# | 2574 | 218f522f-d3b0-4370-a93f-e8a70d958950 |   symptomatic   |   symptomatic    |
# | 5169 | feabf097-bb15-4fdf-85ac-a9babbaf5d9e |   symptomatic   |   symptomatic    |
# | 3589 | a0b0d0bf-51cc-4238-bad5-1b70c6edf438 |     healthy     |     healthy      |
# | 5720 | b54df7b6-c651-40e7-a80d-c0955f1abaa9 |   symptomatic   |   symptomatic    |
# | 486  | 97f284b3-45c9-4262-9d4f-adafe31d6b71 |     healthy     |     healthy      |
# | 5157 | b4d64d96-8bf9-413d-a165-e6deed6c4dba |   symptomatic   |   symptomatic    |
# | 4731 | ae800719-1e77-45cb-9c1d-264eebca44ec |   symptomatic   |   symptomatic    |
# | 4063 | c1281451-b74b-4659-beb7-11669297e022 |   symptomatic   |   symptomatic    |
# | 1670 | dc82a3d2-e9bb-40d2-8451-16ad60e188f2 |     healthy     |     healthy      |
# | 2351 | 651341cb-6be7-4981-b3e0-a454dee3af64 |   symptomatic   |   symptomatic    |
# | 3837 | e56b40e6-935c-41c6-a04f-cfa133d69cec |    COVID-19     |     COVID-19     |
# | 1665 | 0c01c4ac-cfbf-45b9-80db-492f334aaf30 |   symptomatic   |   symptomatic    |
# | 1158 | 8469a131-4174-4d7b-b588-00c9c0f91a28 |   symptomatic   |   symptomatic    |
# | 228  | b68a0a4e-7622-4426-875e-0dd9d6604224 |    COVID-19     |     COVID-19     |
# | 6032 | 583b78b9-ac37-4921-9865-fd6f683ad3e9 |    COVID-19     |     COVID-19     |
# | 2594 | 3df1981c-e380-40bd-ab27-4465eee42d27 |   symptomatic   |   symptomatic    |
# | 2846 | 41c95439-7a27-4f01-8aba-4a0640b4683e |   symptomatic   |   symptomatic    |
# | 6058 | 4d72142f-9932-47f4-8d86-29757ea3f78d |     healthy     |     healthy      |
# | 4962 | 9c121206-2d76-40b1-bbd0-4b1f483adada |     healthy     |     healthy      |
# | 5196 | 95c2af6d-4ed8-4626-88d0-27515a452ffe |     healthy     |     healthy      |
# | 538  | 164ff16d-2af8-4724-9a57-3b3bd7e17839 |   symptomatic   |   symptomatic    |
# | 5110 | de543d13-541c-4ad7-bb3c-c5c302de3aaf |     healthy     |     healthy      |
# | 3250 | 3ef8a638-8f4c-4018-8e25-dfd817979599 |   symptomatic   |   symptomatic    |
# | 2917 | 789d0ab0-077a-4da9-8f51-b964fbe4a2a4 |     healthy     |     healthy      |
# | 1558 | bbd87814-fc8c-493a-907c-aeb18acf8e44 |     healthy     |     healthy      |
# | 5207 | ada1def9-7e36-4d4e-8e3e-e678afee4185 |   symptomatic   |   symptomatic    |
# | 254  | e56b40e6-935c-41c6-a04f-cfa133d69cec |    COVID-19     |     COVID-19     |
# | 5167 | 94bfcb37-906f-4862-9c4e-69b5550e320e |   symptomatic   |   symptomatic    |
# | 4890 | dc2d0ff1-8f06-4deb-a95f-bdac66488319 |     healthy     |     healthy      |
# | 221  | 5be10c89-4c9a-495e-8671-f445f51a3fe0 |   symptomatic   |   symptomatic    |
# | 3176 | 11c1e2d8-52e2-4e32-8ab8-b858268e0ca9 |     healthy     |     healthy      |
# | 2776 | 60ab1646-c540-4179-ae54-ca83767edff1 |    COVID-19     |     healthy      |
# |  65  | 0f22e116-d0d6-4efb-9444-fc351ff5964a |     healthy     |     healthy      |
# | 1253 | bb5fd4d8-a36d-4918-931f-c6bd2adcc20d |   symptomatic   |   symptomatic    |
# | 585  | cc47f830-9785-4651-9756-cde2f39fb494 |    COVID-19     |     COVID-19     |
# | 5135 | 34fd00ad-788a-433c-a0b8-b603b33a589c |     healthy     |     healthy      |
# | 2680 | e89a2e55-e5ad-4774-950c-ae4e84b444f8 |   symptomatic   |   symptomatic    |
# | 5324 | 637d6498-1d52-4860-9976-5a7a94f2a0c3 |    COVID-19     |     COVID-19     |
# | 4431 | 6034baa0-0bb8-4c7e-8699-f4a99b5d728f |   symptomatic   |   symptomatic    |
# | 1507 | d085181f-cd24-464a-9bd2-b8fe313d2321 |   symptomatic   |   symptomatic    |
# | 1706 | b7b6a650-3276-43fb-90b1-73134b483fb6 |    COVID-19     |     COVID-19     |
# | 1446 | 660afa71-ac8d-4824-b751-3d23f4dc0013 |    COVID-19     |     COVID-19     |
# | 6264 | 6604cf63-454a-4b13-9fc9-95eb74566e8e |    COVID-19     |     COVID-19     |
# | 6007 | 7a372c4a-1043-43b1-a03c-f2296dfd6b68 |     healthy     |     healthy      |
# | 1569 | 86bd5780-9af3-4e33-86ba-c0105ecd408e |   symptomatic   |   symptomatic    |
# | 1242 | 092d10af-b848-473c-8dfd-19376b7c587a |   symptomatic   |   symptomatic    |
# | 4985 | 8956ab9c-a0ca-4f2e-ae00-1f5d0065d50b |   symptomatic   |   symptomatic    |
# | 1272 | 8aa95c58-4f0f-4df6-89a2-4b3b5d7841bb |   symptomatic   |   symptomatic    |
# | 5146 | 49cc8b94-838b-4b23-9fb1-8d9384520634 |   symptomatic   |   symptomatic    |
# | 376  | d5a1411d-d312-44b1-a37d-a387ec13df1a |    COVID-19     |     COVID-19     |
# | 543  | 91678983-1d96-4390-8f09-55df6a75bb36 |    COVID-19     |     COVID-19     |
# | 2306 | 727349f2-4730-45f6-99fe-8cf1ae1f2004 |     healthy     |     healthy      |
# | 5437 | c18be4ba-eaa8-487a-9343-2c45af6c60aa |     healthy     |     healthy      |
# | 5572 | 22fd67e4-0911-45f9-8625-1fe8ba4323cf |   symptomatic   |   symptomatic    |
# | 4878 | 9d691598-b7e2-4d3b-a90a-afd4ab47abad |    COVID-19     |     COVID-19     |
# | 5194 | e272246a-5c0e-4549-83b0-8330cfce867e |    COVID-19     |     COVID-19     |
# | 2678 | e89a2e55-e5ad-4774-950c-ae4e84b444f8 |   symptomatic   |   symptomatic    |
# | 177  | 6308bd06-1617-4524-8fc3-b388c2d52499 |   symptomatic   |   symptomatic    |
# | 1195 | add43c2c-298b-421f-86f1-d69bfab218e2 |   symptomatic   |   symptomatic    |
# | 1010 | 32ba514c-b6e5-45a5-a62d-a4555084e3ed |    COVID-19     |     COVID-19     |
# | 812  | 353bb06f-a51c-4646-b890-d7fd3529e0e2 |     healthy     |     healthy      |
# | 6376 | aa27859e-d3a3-4a40-a241-8ebdc849017a |   symptomatic   |   symptomatic    |
# | 501  | a6645b1d-dadc-4258-b03b-c5b3f05d519d |    COVID-19     |     COVID-19     |
# | 4516 | 4e39ad3e-5257-4356-b854-7fb48c6cd1f0 |   symptomatic   |   symptomatic    |
# | 3412 | 431c4a7e-06d9-4fed-9aca-2de718d66f29 |   symptomatic   |   symptomatic    |
# | 681  | dbb52561-93ca-444e-9ff9-e61fd6c6996f |    COVID-19     |     COVID-19     |
# | 5976 | 55c0a763-5f42-476e-9c72-e2924b21b2b4 |   symptomatic   |   symptomatic    |
# | 1235 | 333ca4a1-557a-4be5-b2e3-9e572b3132ff |   symptomatic   |   symptomatic    |
# | 2112 | 7078c585-556f-4e63-8e4f-f82519cf70c1 |   symptomatic   |   symptomatic    |
# | 1730 | 8905d5ea-2412-4222-93f8-95cd4455f8e4 |     healthy     |     healthy      |
# | 5028 | ac4ea2db-4fff-4a7f-a5fe-3a9ade2f1020 |    COVID-19     |     COVID-19     |
# | 746  | c3382b37-9f19-4379-b488-68f636a6c684 |   symptomatic   |   symptomatic    |
# | 5054 | ccdb32af-58f4-4718-9f6e-eec7e0020382 |    COVID-19     |     COVID-19     |
# | 168  | 69317fad-cc19-43fe-8537-782fc415ee7c |   symptomatic   |   symptomatic    |
# | 1773 | ec1c43c9-5043-4735-9f66-905e47e22b48 |    COVID-19     |     COVID-19     |
# | 1672 | dc82a3d2-e9bb-40d2-8451-16ad60e188f2 |     healthy     |     healthy      |
# | 865  | 3c903e81-9634-4d62-90f0-f09b95f382f7 |   symptomatic   |   symptomatic    |
# | 2024 | 1dd3b212-e969-4ede-a9d9-f24b711e2028 |    COVID-19     |     COVID-19     |
# | 2377 | 79221f97-e57f-476c-a8b1-57c65ff4e01c |   symptomatic   |   symptomatic    |
# | 319  | 54138a2b-3f07-44aa-bc08-f254422e32ab |   symptomatic   |   symptomatic    |
# | 2418 | 65be7822-e7c7-4fdc-9549-bf3fac30f919 |    COVID-19     |   symptomatic    |
# | 1385 | 636c468c-d6db-4a7d-8e0e-31c7f68baa49 |   symptomatic   |   symptomatic    |
# | 5773 | 8396e93f-96ff-4fa3-8ef9-41c4d0ee191e |   symptomatic   |   symptomatic    |
# | 6185 | c7aebd2e-f4d8-4af7-82f5-f0d71f93cae2 |   symptomatic   |   symptomatic    |
# | 3113 | 01ff40e8-63e6-4570-a463-9778ea30cad7 |   symptomatic   |   symptomatic    |
# | 3871 | 2532b7ae-20da-4dde-ab4e-46ffe1fdbe77 |     healthy     |     healthy      |
# | 2127 | 2f651988-a4c4-4042-a123-f0cc68a961a5 |     healthy     |     healthy      |
# | 506  | e18efb30-aea1-4cf9-aadb-0afe4c51c7df |    COVID-19     |     COVID-19     |
# | 2900 | 182246b0-9f77-4c40-976e-3c9342619819 |    COVID-19     |     COVID-19     |
# | 216  | 5be10c89-4c9a-495e-8671-f445f51a3fe0 |   symptomatic   |   symptomatic    |
# | 4155 | 191dca0e-7951-4aa3-9764-2761bd511955 |     healthy     |     healthy      |
# +------+--------------------------------------+-----------------+------------------+
#
# No of samples : 602
#
# Batch Accuracy: 93.02%
